# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:/Users/smm/Downloads/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv",encoding='ISO-8859-1')
df2 = pd.read_csv("C:/Users/smm/Downloads/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv",encoding='ISO-8859-1')
df3 = pd.read_csv("C:/Users/smm/Downloads/DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv",encoding='ISO-8859-1')
df4 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv",encoding='ISO-8859-1')
df5 = pd.read_csv("C:/Users/smm/Downloads/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv",encoding='ISO-8859-1')
df6 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv",encoding='ISO-8859-1')
df7 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv",encoding='ISO-8859-1')
df8 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv",encoding='ISO-8859-1')
df9 = pd.read_csv("C:/Users/smm/Downloads/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv",encoding='ISO-8859-1')
df10 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv",encoding='ISO-8859-1')
df11 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv",encoding='ISO-8859-1')
df12 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv",encoding='ISO-8859-1')
df13 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv",encoding='ISO-8859-1')
df14 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv",encoding='ISO-8859-1')
df15 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv",encoding='ISO-8859-1')
df16 = pd.read_csv( "C:/Users/smm/Downloads/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv",encoding='ISO-8859-1')
df17 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv",encoding='ISO-8859-1')
df18 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv",encoding='ISO-8859-1')
df19 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv",encoding='ISO-8859-1')
df20 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv",encoding='ISO-8859-1')
df21 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv",encoding='ISO-8859-1')
df22 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv",encoding='ISO-8859-1')
df23 = pd.read_csv(  "C:/Users/smm/Downloads/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv",encoding='ISO-8859-1')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23])
df.head()
# Out:
#   State Code District Code    India/States Division Group  Class  \
# 0        `21          `000  STATE - ODISHA      `00  `000  `0000
# 1        `21          `000  STATE - ODISHA      `01  `000  `0000
# 2        `21          `000  STATE - ODISHA      `01  `011  `0000
# 3        `21          `000  STATE - ODISHA      `01  `011  `0111
# 4        `21          `000  STATE - ODISHA      `01  `011  `0112
#
#                                             NIC Name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#    Main Workers - Total -  Persons  Main Workers - Total - Males  \
# 0                           630079                        447722
# 1                            18891                         13846
# 2                              253                           191
# 3                               33                            31
# 4                               40                            28
#
#    Main Workers - Total - Females  ...  Main Workers - Urban - Females  \
# 0                          182357  ...                           37858
# 1                            5045  ...                             568
# 2                              62  ...                               4
# 3                               2  ...                               0
# 4                              12  ...                               0
#
#    Marginal Workers - Total -  Persons  Marginal Workers - Total - Males  \
# 0                               434062                            195937
# 1                                23401                             12168
# 2                                  323                               144
# 3                                   57                                32
# 4                                   37                                26
#
#    Marginal Workers - Total - Females  Marginal Workers - Rural -  Persons  \
# 0                              238125                               398262
# 1                               11233                                22398
# 2                                 179                                  266
# 3                                  25                                   45
# 4                                  11                                   32
#
#    Marginal Workers - Rural - Males  Marginal Workers - Rural - Females  \
# 0                            175831                              222431
# 1                             11595                               10803
# 2                               117                                 149
# 3                                26                                  19
# 4                                21                                  11
#
#    Marginal Workers - Urban -  Persons  Marginal Workers - Urban - Males  \
# 0                                35800                             20106
# 1                                 1003                               573
# 2                                   57                                27
# 3                                   12                                 6
# 4                                    5                                 5
#
#    Marginal Workers - Urban - Females
# 0                               15694
# 1                                 430
# 2                                  30
# 3                                   6
# 4                                   0
#
# [5 rows x 25 columns]

# %%
df.to_csv("C:/Users/smm/Downloads/ResaleFlatPrices_combaine.csv", index= False)

# %%
# remove unnec comma, semi colon,
df['State Code'] = df['State Code'].astype(str).str.replace('`', '').astype(int)
df['District Code'] = df['District Code'].astype(str).str.replace('`', '').astype(int)
df['Division'] = df['Division'].astype(str).str.replace('`', '').astype(int)
df['Group'] = df['Group'].astype(str).str.replace('`', '').astype(int)
df['Class'] = df['Class'].astype(str).str.replace('`', '').astype(int)

# %%
df.columns
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %%
# remove spl char

def remove_sp_char(column_name):
    return ''.join(e for e in column_name if e.isalnum() or e in ('_', '.'))

df.columns = [remove_sp_char(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['StateCode', 'DistrictCode', 'IndiaStates', 'Division', 'Group',
#        'Class', 'NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
df.head()
# Out:
#    StateCode  DistrictCode     IndiaStates  Division  Group  Class  \
# 0         21             0  STATE - ODISHA         0      0      0
# 1         21             0  STATE - ODISHA         1      0      0
# 2         21             0  STATE - ODISHA         1     11      0
# 3         21             0  STATE - ODISHA         1     11    111
# 4         21             0  STATE - ODISHA         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                   630079
# 1  Crop and animal production, hunting and relate...                    18891
# 2                     Growing of non-perennial crops                      253
# 3  Growing of cereals (except rice), leguminous c...                       33
# 4                                    Growing of rice                       40
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# 0                 447722                   182357  ...
# 1                  13846                     5045  ...
# 2                    191                       62  ...
# 3                     31                        2  ...
# 4                     28                       12  ...
#
#    MainWorkersUrbanFemales  MarginalWorkersTotalPersons  \
# 0                    37858                       434062
# 1                      568                        23401
# 2                        4                          323
# 3                        0                           57
# 4                        0                           37
#
#    MarginalWorkersTotalMales  MarginalWorkersTotalFemales  \
# 0                     195937                       238125
# 1                      12168                        11233
# 2                        144                          179
# 3                         32                           25
# 4                         26                           11
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                       398262                     175831
# 1                        22398                      11595
# 2                          266                        117
# 3                           45                         26
# 4                           32                         21
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                       222431                        35800
# 1                        10803                         1003
# 2                          149                           57
# 3                           19                           12
# 4                           11                            5
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales
# 0                      20106                        15694
# 1                        573                          430
# 2                         27                           30
# 3                          6                            6
# 4                          5                            0
#
# [5 rows x 25 columns]

# %% [markdown]
# EDA

# %%
non_numeric_columns =df.select_dtypes(exclude=[float, int]).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Calculate correlation
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                              StateCode  DistrictCode  Division     Group  \
# StateCode                     1.000000      0.851207 -0.010642 -0.001695
# DistrictCode                  0.851207      1.000000 -0.005517 -0.005349
# Division                     -0.010642     -0.005517  1.000000  0.744991
# Group                        -0.001695     -0.005349  0.744991  1.000000
# Class                         0.003277     -0.004001  0.438274  0.593097
# MainWorkersTotalPersons      -0.003645     -0.028298 -0.010332 -0.014413
# MainWorkersTotalMales        -0.004775     -0.027999 -0.010797 -0.014439
# MainWorkersTotalFemales       0.001599     -0.027503 -0.007516 -0.013226
# MainWorkersRuralPersons      -0.004710     -0.028544 -0.013753 -0.016427
# MainWorkersRuralMales        -0.005690     -0.028156 -0.013073 -0.015752
# MainWorkersRuralFemales      -0.000498     -0.027300 -0.015046 -0.017440
# MainWorkersUrbanPersons      -0.002714     -0.027413 -0.007376 -0.012471
# MainWorkersUrbanMales        -0.003972     -0.027262 -0.008823 -0.013119
# MainWorkersUrbanFemales       0.003503     -0.026093  0.000091 -0.008444
# MarginalWorkersTotalPersons  -0.005332     -0.027705 -0.011351 -0.014618
# MarginalWorkersTotalMales    -0.003995     -0.027672 -0.011699 -0.015023
# MarginalWorkersTotalFemales  -0.006299     -0.026415 -0.010492 -0.013552
# MarginalWorkersRuralPersons  -0.007676     -0.028375 -0.014724 -0.016540
# MarginalWorkersRuralMales    -0.006013     -0.028293 -0.014173 -0.016435
# MarginalWorkersRuralFemales  -0.008593     -0.027010 -0.014414 -0.015789
# MarginalWorkersUrbanPersons   0.000114     -0.024065 -0.003224 -0.009337
# MarginalWorkersUrbanMales    -0.000294     -0.025354 -0.006859 -0.011886
# MarginalWorkersUrbanFemales   0.000589     -0.021301  0.001242 -0.005841
#
#                                 Class  MainWorkersTotalPersons  \
# StateCode                    0.003277                -0.003645
# DistrictCode                -0.004001                -0.028298
# Division                     0.438274                -0.010332
# Group                        0.593097                -0.014413
# Class                        1.000000                -0.011074
# MainWorkersTotalPersons     -0.011074                 1.000000
# MainWorkersTotalMales       -0.010969                 0.996935
# MainWorkersTotalFemales     -0.010713                 0.938961
# MainWorkersRuralPersons     -0.012066                 0.982750
# MainWorkersRuralMales       -0.011600                 0.981071
# MainWorkersRuralFemales     -0.012695                 0.895108
# MainWorkersUrbanPersons     -0.010021                 0.989260
# MainWorkersUrbanMales       -0.010245                 0.987095
# MainWorkersUrbanFemales     -0.008203                 0.926007
# MarginalWorkersTotalPersons -0.010986                 0.931390
# MarginalWorkersTotalMales   -0.011278                 0.962609
# MarginalWorkersTotalFemales -0.010196                 0.858475
# MarginalWorkersRuralPersons -0.011908                 0.904754
# MarginalWorkersRuralMales   -0.011956                 0.942542
# MarginalWorkersRuralFemales -0.011270                 0.829537
# MarginalWorkersUrbanPersons -0.008139                 0.914343
# MarginalWorkersUrbanMales   -0.009593                 0.954722
# MarginalWorkersUrbanFemales -0.005999                 0.819452
#
#                              MainWorkersTotalMales  MainWorkersTotalFemales  \
# StateCode                                -0.004775                 0.001599
# DistrictCode                             -0.027999                -0.027503
# Division                                 -0.010797                -0.007516
# Group                                    -0.014439                -0.013226
# Class                                    -0.010969                -0.010713
# MainWorkersTotalPersons                   0.996935                 0.938961
# MainWorkersTotalMales                     1.000000                 0.909170
# MainWorkersTotalFemales                   0.909170                 1.000000
# MainWorkersRuralPersons                   0.978081                 0.930049
# MainWorkersRuralMales                     0.983617                 0.896767
# MainWorkersRuralFemales                   0.863221                 0.968629
# MainWorkersUrbanPersons                   0.987538                 0.923119
# MainWorkersUrbanMales                     0.990488                 0.898621
# MainWorkersUrbanFemales                   0.899947                 0.971606
# MarginalWorkersTotalPersons               0.917952                 0.921079
# MarginalWorkersTotalMales                 0.960615                 0.899647
# MarginalWorkersTotalFemales               0.835229                 0.896725
# MarginalWorkersRuralPersons               0.891626                 0.895065
# MarginalWorkersRuralMales                 0.941126                 0.878534
# MarginalWorkersRuralFemales               0.807887                 0.862926
# MarginalWorkersUrbanPersons               0.901310                 0.903520
# MarginalWorkersUrbanMales                 0.951808                 0.896394
# MarginalWorkersUrbanFemales               0.795125                 0.865368
#
#                              MainWorkersRuralPersons  MainWorkersRuralMales  \
# StateCode                                  -0.004710              -0.005690
# DistrictCode                               -0.028544              -0.028156
# Division                                   -0.013753              -0.013073
# Group                                      -0.016427              -0.015752
# Class                                      -0.012066              -0.011600
# MainWorkersTotalPersons                     0.982750               0.981071
# MainWorkersTotalMales                       0.978081               0.983617
# MainWorkersTotalFemales                     0.930049               0.896767
# MainWorkersRuralPersons                     1.000000               0.994983
# MainWorkersRuralMales                       0.994983               1.000000
# MainWorkersRuralFemales                     0.923504               0.880497
# MainWorkersUrbanPersons                     0.945163               0.946163
# MainWorkersUrbanMales                       0.943646               0.949457
# MainWorkersUrbanFemales                     0.882093               0.860010
# MarginalWorkersTotalPersons                 0.944638               0.928626
# MarginalWorkersTotalMales                   0.967549               0.968135
# MarginalWorkersTotalFemales                 0.878677               0.848275
# MarginalWorkersRuralPersons                 0.937471               0.919353
# MarginalWorkersRuralMales                   0.968126               0.968428
# MarginalWorkersRuralFemales                 0.866199               0.834551
# MarginalWorkersUrbanPersons                 0.884830               0.874606
# MarginalWorkersUrbanMales                   0.923402               0.924458
# MarginalWorkersUrbanFemales                 0.793600               0.770562
#
#                              ...  MainWorkersUrbanFemales  \
# StateCode                    ...                 0.003503
# DistrictCode                 ...                -0.026093
# Division                     ...                 0.000091
# Group                        ...                -0.008444
# Class                        ...                -0.008203
# MainWorkersTotalPersons      ...                 0.926007
# MainWorkersTotalMales        ...                 0.899947
# MainWorkersTotalFemales      ...                 0.971606
# MainWorkersRuralPersons      ...                 0.882093
# MainWorkersRuralMales        ...                 0.860010
# MainWorkersRuralFemales      ...                 0.882326
# MainWorkersUrbanPersons      ...                 0.938144
# MainWorkersUrbanMales        ...                 0.910616
# MainWorkersUrbanFemales      ...                 1.000000
# MarginalWorkersTotalPersons  ...                 0.872630
# MarginalWorkersTotalMales    ...                 0.872908
# MarginalWorkersTotalFemales  ...                 0.830766
# MarginalWorkersRuralPersons  ...                 0.821844
# MarginalWorkersRuralMales    ...                 0.831390
# MarginalWorkersRuralFemales  ...                 0.772949
# MarginalWorkersUrbanPersons  ...                 0.911994
# MarginalWorkersUrbanMales    ...                 0.906471
# MarginalWorkersUrbanFemales  ...                 0.871509
#
#                              MarginalWorkersTotalPersons  \
# StateCode                                      -0.005332
# DistrictCode                                   -0.027705
# Division                                       -0.011351
# Group                                          -0.014618
# Class                                          -0.010986
# MainWorkersTotalPersons                         0.931390
# MainWorkersTotalMales                           0.917952
# MainWorkersTotalFemales                         0.921079
# MainWorkersRuralPersons                         0.944638
# MainWorkersRuralMales                           0.928626
# MainWorkersRuralFemales                         0.915601
# MainWorkersUrbanPersons                         0.898218
# MainWorkersUrbanMales                           0.889594
# MainWorkersUrbanFemales                         0.872630
# MarginalWorkersTotalPersons                     1.000000
# MarginalWorkersTotalMales                       0.972667
# MarginalWorkersTotalFemales                     0.977270
# MarginalWorkersRuralPersons                     0.988355
# MarginalWorkersRuralMales                       0.967617
# MarginalWorkersRuralFemales                     0.954814
# MarginalWorkersUrbanPersons                     0.945380
# MarginalWorkersUrbanMales                       0.938114
# MarginalWorkersUrbanFemales                     0.905235
#
#                              MarginalWorkersTotalMales  \
# StateCode                                    -0.003995
# DistrictCode                                 -0.027672
# Division                                     -0.011699
# Group                                        -0.015023
# Class                                        -0.011278
# MainWorkersTotalPersons                       0.962609
# MainWorkersTotalMales                         0.960615
# MainWorkersTotalFemales                       0.899647
# MainWorkersRuralPersons                       0.967549
# MainWorkersRuralMales                         0.968135
# MainWorkersRuralFemales                       0.872677
# MainWorkersUrbanPersons                       0.935242
# MainWorkersUrbanMales                         0.933726
# MainWorkersUrbanFemales                       0.872908
# MarginalWorkersTotalPersons                   0.972667
# MarginalWorkersTotalMales                     1.000000
# MarginalWorkersTotalFemales                   0.901331
# MarginalWorkersRuralPersons                   0.950092
# MarginalWorkersRuralMales                     0.990756
# MarginalWorkersRuralFemales                   0.870336
# MarginalWorkersUrbanPersons                   0.943636
# MarginalWorkersUrbanMales                     0.971552
# MarginalWorkersUrbanFemales                   0.861974
#
#                              MarginalWorkersTotalFemales  \
# StateCode                                      -0.006299
# DistrictCode                                   -0.026415
# Division                                       -0.010492
# Group                                          -0.013552
# Class                                          -0.010196
# MainWorkersTotalPersons                         0.858475
# MainWorkersTotalMales                           0.835229
# MainWorkersTotalFemales                         0.896725
# MainWorkersRuralPersons                         0.878677
# MainWorkersRuralMales                           0.848275
# MainWorkersRuralFemales                         0.911129
# MainWorkersUrbanPersons                         0.821584
# MainWorkersUrbanMales                           0.806883
# MainWorkersUrbanFemales                         0.830766
# MarginalWorkersTotalPersons                     0.977270
# MarginalWorkersTotalMales                       0.901331
# MarginalWorkersTotalFemales                     1.000000
# MarginalWorkersRuralPersons                     0.976159
# MarginalWorkersRuralMales                       0.900352
# MarginalWorkersRuralFemales                     0.986411
# MarginalWorkersUrbanPersons                     0.901893
# MarginalWorkersUrbanMales                       0.862854
# MarginalWorkersUrbanFemales                     0.901566
#
#                              MarginalWorkersRuralPersons  \
# StateCode                                      -0.007676
# DistrictCode                                   -0.028375
# Division                                       -0.014724
# Group                                          -0.016540
# Class                                          -0.011908
# MainWorkersTotalPersons                         0.904754
# MainWorkersTotalMales                           0.891626
# MainWorkersTotalFemales                         0.895065
# MainWorkersRuralPersons                         0.937471
# MainWorkersRuralMales                           0.919353
# MainWorkersRuralFemales                         0.917198
# MainWorkersUrbanPersons                         0.856844
# MainWorkersUrbanMales                           0.850832
# MainWorkersUrbanFemales                         0.821844
# MarginalWorkersTotalPersons                     0.988355
# MarginalWorkersTotalMales                       0.950092
# MarginalWorkersTotalFemales                     0.976159
# MarginalWorkersRuralPersons                     1.000000
# MarginalWorkersRuralMales                       0.963865
# MarginalWorkersRuralFemales                     0.977944
# MarginalWorkersUrbanPersons                     0.884770
# MarginalWorkersUrbanMales                       0.883685
# MarginalWorkersUrbanFemales                     0.840440
#
#                              MarginalWorkersRuralMales  \
# StateCode                                    -0.006013
# DistrictCode                                 -0.028293
# Division                                     -0.014173
# Group                                        -0.016435
# Class                                        -0.011956
# MainWorkersTotalPersons                       0.942542
# MainWorkersTotalMales                         0.941126
# MainWorkersTotalFemales                       0.878534
# MainWorkersRuralPersons                       0.968126
# MainWorkersRuralMales                         0.968428
# MainWorkersRuralFemales                       0.874288
# MainWorkersUrbanPersons                       0.899349
# MainWorkersUrbanMales                         0.899567
# MainWorkersUrbanFemales                       0.831390
# MarginalWorkersTotalPersons                   0.967617
# MarginalWorkersTotalMales                     0.990756
# MarginalWorkersTotalFemales                   0.900352
# MarginalWorkersRuralPersons                   0.963865
# MarginalWorkersRuralMales                     1.000000
# MarginalWorkersRuralFemales                   0.886966
# MarginalWorkersUrbanPersons                   0.898665
# MarginalWorkersUrbanMales                     0.930444
# MarginalWorkersUrbanFemales                   0.814755
#
#                              MarginalWorkersRuralFemales  \
# StateCode                                      -0.008593
# DistrictCode                                   -0.027010
# Division                                       -0.014414
# Group                                          -0.015789
# Class                                          -0.011270
# MainWorkersTotalPersons                         0.829537
# MainWorkersTotalMales                           0.807887
# MainWorkersTotalFemales                         0.862926
# MainWorkersRuralPersons                         0.866199
# MainWorkersRuralMales                           0.834551
# MainWorkersRuralFemales                         0.904626
# MainWorkersUrbanPersons                         0.780343
# MainWorkersUrbanMales                           0.769749
# MainWorkersUrbanFemales                         0.772949
# MarginalWorkersTotalPersons                     0.954814
# MarginalWorkersTotalMales                       0.870336
# MarginalWorkersTotalFemales                     0.986411
# MarginalWorkersRuralPersons                     0.977944
# MarginalWorkersRuralMales                       0.886966
# MarginalWorkersRuralFemales                     1.000000
# MarginalWorkersUrbanPersons                     0.829293
# MarginalWorkersUrbanMales                       0.802496
# MarginalWorkersUrbanFemales                     0.818232
#
#                              MarginalWorkersUrbanPersons  \
# StateCode                                       0.000114
# DistrictCode                                   -0.024065
# Division                                       -0.003224
# Group                                          -0.009337
# Class                                          -0.008139
# MainWorkersTotalPersons                         0.914343
# MainWorkersTotalMales                           0.901310
# MainWorkersTotalFemales                         0.903520
# MainWorkersRuralPersons                         0.884830
# MainWorkersRuralMales                           0.874606
# MainWorkersRuralFemales                         0.839329
# MainWorkersUrbanPersons                         0.915382
# MainWorkersUrbanMales                           0.901849
# MainWorkersUrbanFemales                         0.911994
# MarginalWorkersTotalPersons                     0.945380
# MarginalWorkersTotalMales                       0.943636
# MarginalWorkersTotalFemales                     0.901893
# MarginalWorkersRuralPersons                     0.884770
# MarginalWorkersRuralMales                       0.898665
# MarginalWorkersRuralFemales                     0.829293
# MarginalWorkersUrbanPersons                     1.000000
# MarginalWorkersUrbanMales                       0.980072
# MarginalWorkersUrbanFemales                     0.972015
#
#                              MarginalWorkersUrbanMales  \
# StateCode                                    -0.000294
# DistrictCode                                 -0.025354
# Division                                     -0.006859
# Group                                        -0.011886
# Class                                        -0.009593
# MainWorkersTotalPersons                       0.954722
# MainWorkersTotalMales                         0.951808
# MainWorkersTotalFemales                       0.896394
# MainWorkersRuralPersons                       0.923402
# MainWorkersRuralMales                         0.924458
# MainWorkersRuralFemales                       0.830955
# MainWorkersUrbanPersons                       0.956206
# MainWorkersUrbanMales                         0.951729
# MainWorkersUrbanFemales                       0.906471
# MarginalWorkersTotalPersons                   0.938114
# MarginalWorkersTotalMales                     0.971552
# MarginalWorkersTotalFemales                   0.862854
# MarginalWorkersRuralPersons                   0.883685
# MarginalWorkersRuralMales                     0.930444
# MarginalWorkersRuralFemales                   0.802496
# MarginalWorkersUrbanPersons                   0.980072
# MarginalWorkersUrbanMales                     1.000000
# MarginalWorkersUrbanFemales                   0.905978
#
#                              MarginalWorkersUrbanFemales
# StateCode                                       0.000589
# DistrictCode                                   -0.021301
# Division                                        0.001242
# Group                                          -0.005841
# Class                                          -0.005999
# MainWorkersTotalPersons                         0.819452
# MainWorkersTotalMales                           0.795125
# MainWorkersTotalFemales                         0.865368
# MainWorkersRuralPersons                         0.793600
# MainWorkersRuralMales                           0.770562
# MainWorkersRuralFemales                         0.805962
# MainWorkersUrbanPersons                         0.819911
# MainWorkersUrbanMales                           0.796367
# MainWorkersUrbanFemales                         0.871509
# MarginalWorkersTotalPersons                     0.905235
# MarginalWorkersTotalMales                       0.861974
# MarginalWorkersTotalFemales                     0.901566
# MarginalWorkersRuralPersons                     0.840440
# MarginalWorkersRuralMales                       0.814755
# MarginalWorkersRuralFemales                     0.818232
# MarginalWorkersUrbanPersons                     0.972015
# MarginalWorkersUrbanMales                       0.905978
# MarginalWorkersUrbanFemales                     1.000000
#
# [23 rows x 23 columns]

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.head()
# Out:
#    StateCode  DistrictCode     IndiaStates  Division  Group  Class  \
# 0         21             0  STATE - ODISHA         0      0      0
# 1         21             0  STATE - ODISHA         1      0      0
# 2         21             0  STATE - ODISHA         1     11      0
# 3         21             0  STATE - ODISHA         1     11    111
# 4         21             0  STATE - ODISHA         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                   630079
# 1  Crop and animal production, hunting and relate...                    18891
# 2                     Growing of non-perennial crops                      253
# 3  Growing of cereals (except rice), leguminous c...                       33
# 4                                    Growing of rice                       40
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# 0                 447722                   182357  ...
# 1                  13846                     5045  ...
# 2                    191                       62  ...
# 3                     31                        2  ...
# 4                     28                       12  ...
#
#    MainWorkersUrbanFemales  MarginalWorkersTotalPersons  \
# 0                    37858                       434062
# 1                      568                        23401
# 2                        4                          323
# 3                        0                           57
# 4                        0                           37
#
#    MarginalWorkersTotalMales  MarginalWorkersTotalFemales  \
# 0                     195937                       238125
# 1                      12168                        11233
# 2                        144                          179
# 3                         32                           25
# 4                         26                           11
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                       398262                     175831
# 1                        22398                      11595
# 2                          266                        117
# 3                           45                         26
# 4                           32                         21
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                       222431                        35800
# 1                        10803                         1003
# 2                          149                           57
# 3                           19                           12
# 4                           11                            5
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales
# 0                      20106                        15694
# 1                        573                          430
# 2                         27                           30
# 3                          6                            6
# 4                          5                            0
#
# [5 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# StateCode                      0
# DistrictCode                   0
# IndiaStates                    0
# Division                       0
# Group                          0
# Class                          0
# NICName                        0
# MainWorkersTotalPersons        0
# MainWorkersTotalMales          0
# MainWorkersTotalFemales        0
# MainWorkersRuralPersons        0
# MainWorkersRuralMales          0
# MainWorkersRuralFemales        0
# MainWorkersUrbanPersons        0
# MainWorkersUrbanMales          0
# MainWorkersUrbanFemales        0
# MarginalWorkersTotalPersons    0
# MarginalWorkersTotalMales      0
# MarginalWorkersTotalFemales    0
# MarginalWorkersRuralPersons    0
# MarginalWorkersRuralMales      0
# MarginalWorkersRuralFemales    0
# MarginalWorkersUrbanPersons    0
# MarginalWorkersUrbanMales      0
# MarginalWorkersUrbanFemales    0
# dtype: int64

# %%
df.describe().T
# Out:
#                                 count         mean           std  min    25%  \
# StateCode                    195145.0    19.178278      9.057612  2.0   10.0
# DistrictCode                 195145.0   332.223377    196.176206  0.0  153.0
# Division                     195145.0    46.590351     28.800311  0.0   23.0
# Group                        195145.0   389.422404    313.186034  0.0  103.0
# Class                        195145.0  2293.804709   3059.131669  0.0    0.0
# MainWorkersTotalPersons      195145.0  1492.137518  45681.690979  0.0    6.0
# MainWorkersTotalMales        195145.0  1193.171150  37739.170774  0.0    6.0
# MainWorkersTotalFemales      195145.0   298.966369   8582.018644  0.0    0.0
# MainWorkersRuralPersons      195145.0   660.618719  20444.364940  0.0    2.0
# MainWorkersRuralMales        195145.0   517.035312  16542.946109  0.0    1.0
# MainWorkersRuralFemales      195145.0   143.583407   4314.446369  0.0    0.0
# MainWorkersUrbanPersons      195145.0   831.518799  25867.811792  0.0    2.0
# MainWorkersUrbanMales        195145.0   676.135837  21673.393792  0.0    1.0
# MainWorkersUrbanFemales      195145.0   155.382961   4531.592781  0.0    0.0
# MarginalWorkersTotalPersons  195145.0   364.267186  11769.400296  0.0    0.0
# MarginalWorkersTotalMales    195145.0   182.632197   5760.575239  0.0    0.0
# MarginalWorkersTotalFemales  195145.0   181.634989   6309.699294  0.0    0.0
# MarginalWorkersRuralPersons  195145.0   250.228620   8232.274167  0.0    0.0
# MarginalWorkersRuralMales    195145.0   116.524103   3723.077805  0.0    0.0
# MarginalWorkersRuralFemales  195145.0   133.704517   4748.460092  0.0    0.0
# MarginalWorkersUrbanPersons  195145.0   114.038566   3842.888809  0.0    0.0
# MarginalWorkersUrbanMales    195145.0    66.108094   2132.581727  0.0    0.0
# MarginalWorkersUrbanFemales  195145.0    47.930472   1803.271234  0.0    0.0
#
#                                50%     75%         max
# StateCode                     19.0    27.0        34.0
# DistrictCode                 332.0   516.0       637.0
# Division                      46.0    70.0        99.0
# Group                        370.0   631.0       992.0
# Class                        113.0  4659.0      9920.0
# MainWorkersTotalPersons       28.0   188.0  15619759.0
# MainWorkersTotalMales         23.0   145.0  12801403.0
# MainWorkersTotalFemales        3.0    24.0   2818356.0
# MainWorkersRuralPersons       12.0    74.0   6770444.0
# MainWorkersRuralMales          8.0    56.0   5446541.0
# MainWorkersRuralFemales        0.0     8.0   1323903.0
# MainWorkersUrbanPersons       12.0    86.0   8849315.0
# MainWorkersUrbanMales          9.0    67.0   7354862.0
# MainWorkersUrbanFemales        0.0    12.0   1494453.0
# MarginalWorkersTotalPersons    4.0    28.0   3834122.0
# MarginalWorkersTotalMales      2.0    18.0   1966750.0
# MarginalWorkersTotalFemales    0.0     6.0   1867372.0
# MarginalWorkersRuralPersons    1.0    14.0   2515182.0
# MarginalWorkersRuralMales      0.0     8.0   1223824.0
# MarginalWorkersRuralFemales    0.0     3.0   1291358.0
# MarginalWorkersUrbanPersons    0.0     9.0   1318940.0
# MarginalWorkersUrbanMales      0.0     6.0    742926.0
# MarginalWorkersUrbanFemales    0.0     2.0    576014.0

# %%
df.nunique()
# Out:
# StateCode                        23
# DistrictCode                    472
# IndiaStates                     491
# Division                         89
# Group                           241
# Class                           423
# NICName                         587
# MainWorkersTotalPersons        8679
# MainWorkersTotalMales          7811
# MainWorkersTotalFemales        3970
# MainWorkersRuralPersons        5767
# MainWorkersRuralMales          5218
# MainWorkersRuralFemales        2694
# MainWorkersUrbanPersons        6561
# MainWorkersUrbanMales          5934
# MainWorkersUrbanFemales        2929
# MarginalWorkersTotalPersons    4208
# MarginalWorkersTotalMales      3181
# MarginalWorkersTotalFemales    2850
# MarginalWorkersRuralPersons    3406
# MarginalWorkersRuralMales      2535
# MarginalWorkersRuralFemales    2379
# MarginalWorkersUrbanPersons    2421
# MarginalWorkersUrbanMales      1951
# MarginalWorkersUrbanFemales    1557
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt   
sns.histplot(x = 'IndiaStates', data = df, )
plt.show()

# %%
x_var = "MarginalWorkersTotalPersons"
y_var = "MainWorkersTotalPersons"
sns.boxplot(x = x_var, y = y_var, data = df)
plt.show()
# Out:
# C:\Users\smm\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
y_var = "MainWorkersTotalPersons".strip()
sns.scatterplot(x = 'StateCode', y = y_var, data = df)
plt.xlabel('StateCode')
plt.ylabel('NumberofMainWorkers')
plt.title(' StateCode')
plt.show()

# %%
sns.boxplot( x = "NICName", y = 'MarginalWorkersTotalPersons', data = df)
plt.show()
# Out:
# C:\Users\smm\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\smm\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Datas cleaning procedures

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13825    False
# 13826    False
# 13827    False
# 13828    False
# 13829    False
# Length: 195145, dtype: bool

# %%
df.dtypes
# Out:
# StateCode                       int32
# DistrictCode                    int32
# IndiaStates                    object
# Division                        int32
# Group                           int32
# Class                           int32
# NICName                        object
# MainWorkersTotalPersons         int64
# MainWorkersTotalMales           int64
# MainWorkersTotalFemales         int64
# MainWorkersRuralPersons         int64
# MainWorkersRuralMales           int64
# MainWorkersRuralFemales         int64
# MainWorkersUrbanPersons         int64
# MainWorkersUrbanMales           int64
# MainWorkersUrbanFemales         int64
# MarginalWorkersTotalPersons     int64
# MarginalWorkersTotalMales       int64
# MarginalWorkersTotalFemales     int64
# MarginalWorkersRuralPersons     int64
# MarginalWorkersRuralMales       int64
# MarginalWorkersRuralFemales     int64
# MarginalWorkersUrbanPersons     int64
# MarginalWorkersUrbanMales       int64
# MarginalWorkersUrbanFemales     int64
# dtype: object

# %%
# Drop un nec cols
columns_to_drop = ["StateCode", "DistrictCode", "Division", "Group", "Class"]
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['IndiaStates', 'NICName', 'MainWorkersTotalPersons',
#        'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#        'MainWorkersRuralPersons', 'MainWorkersRuralMales',
#        'MainWorkersRuralFemales', 'MainWorkersUrbanPersons',
#        'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#        'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales',
#        'MarginalWorkersTotalFemales', 'MarginalWorkersRuralPersons',
#        'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
#        'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales',
#        'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
# Extract 'State' and 'District' from 'India/States' column
df[['State', 'District']] = df['IndiaStates'].str.extract(r'STATE - (\w+)|District - (\w+)', expand=True)
df = df.drop('IndiaStates', axis=1)

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       180430
# District     14715
# dtype: int64

# %%
# Fill NaN values in 'State' column with forward fill (ffill)
df['State'] = df['State'].ffill()
df['District'] = df['District'].bfill()

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       0
# District    0
# dtype: int64

# %% [markdown]
# Feature Engrr

# %%
# Example: Creating a new 'TotalWorkers' column by summing 'MainWorkersTotalPersons' and 'MarginalWorkersTotalPersons'
df['TotalWorkers'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['MaleFemaleRatio'] = df['MainWorkersTotalMales'] / (df['MainWorkersTotalFemales'].replace(0, 1))

# %%
df[['TotalWorkers', 'MaleFemaleRatio']].isnull().sum()
# Out:
# TotalWorkers       0
# MaleFemaleRatio    0
# dtype: int64

# %%
df['TotalPopulation'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['WorkersRatio'] = df['TotalWorkers'] / df['TotalPopulation']

# %%
df[['TotalPopulation', 'WorkersRatio']].isnull().sum()
# Out:
# TotalPopulation    0
# WorkersRatio       0
# dtype: int64

# %%
df[['TotalPopulation', 'WorkersRatio']] = df[['TotalPopulation', 'WorkersRatio']].astype(int)

# %%
# # download cleaned df
df.to_csv("HRM.csv", index = False)

# %% [markdown]
# Geo maps creation

# %%
# Replace 'file_path' with the path to your CSV file
file_path = r'C:/Users/smm/Downloads/lat_long.csv'

df_geo = pd.read_csv(file_path)

# %%
df_geo.nunique()
# Out:
# Unnamed: 0    33
# State.Name    33
# latitude      33
# longitude     32
# dtype: int64

# %%
# Drop the specified columns
df_geo = df_geo.drop(['Unnamed: 0', 'State.Name'], axis=1)

# %%
# Concatenate the two DataFrames horizontally (along columns) based on their index
df_1 = pd.concat([df, df_geo[['latitude', 'longitude']]], axis=1)

# %%
df_1.head()
# Out:
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                   630079
# 1  Crop and animal production, hunting and relate...                    18891
# 2                     Growing of non-perennial crops                      253
# 3  Growing of cereals (except rice), leguminous c...                       33
# 4                                    Growing of rice                       40
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                 447722                   182357                   482453
# 1                  13846                     5045                    16426
# 2                    191                       62                      165
# 3                     31                        2                       21
# 4                     28                       12                       34
#
#    MainWorkersRuralMales  MainWorkersRuralFemales  MainWorkersUrbanPersons  \
# 0                 337954                   144499                   147626
# 1                  11949                     4477                     2465
# 2                    107                       58                       88
# 3                     19                        2                       12
# 4                     22                       12                        6
#
#    MainWorkersUrbanMales  MainWorkersUrbanFemales  ...  \
# 0                 109768                    37858  ...
# 1                   1897                      568  ...
# 2                     84                        4  ...
# 3                     12                        0  ...
# 4                      6                        0  ...
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales   State  District  \
# 0                      20106                        15694  ODISHA   Bargarh
# 1                        573                          430  ODISHA   Bargarh
# 2                         27                           30  ODISHA   Bargarh
# 3                          6                            6  ODISHA   Bargarh
# 4                          5                            0  ODISHA   Bargarh
#
#    TotalWorkers  MaleFemaleRatio  TotalPopulation  WorkersRatio   latitude  \
# 0       1064141         2.455195          1064141             1  11.667026
# 1         42292         2.744500            42292             1  14.750429
# 2           576         3.080645              576             1  27.100399
# 3            90        15.500000               90             1  26.749981
# 4            77         2.333333               77             1  25.785414
#
#    longitude
# 0  92.735983
# 1  78.570026
# 2  93.616601
# 3  94.216667
# 4  87.479973
#
# [5 rows x 27 columns]

# %%
df_1.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_1[['latitude', 'longitude', ]].isnull().sum()
# Out:
# latitude     194386
# longitude    194386
# dtype: int64

# %%
# # Drop the  column
# # Drop duplicate 'longitude' column
# df_1 = df_1.loc[:,~df_1.columns.duplicated()]

# # # Check for the presence of both latitude and longitude
# # if 'latitude' not in df_1.columns:
# #     # Calculate the mean of the 'Latitude' and 'Longitude' columns
# #     mean_latitude = df_1['latitude'].mean()
# #     mean_longitude = df_1['longitude'].mean()

# #     # Fill the missing values with their respective mean values
# #     df_1.loc[:, 'latitude'] = df_1['latitude'].fillna(mean_latitude)
# #     df_1.loc[:, 'longitude'] = df_1['longitude'].fillna(mean_longitude)

# %%
df_1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13825     True
# 13826    False
# 13827     True
# 13828    False
# 13829     True
# Length: 195145, dtype: bool

# %%
df_1.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Calculate the mean of the 'Latitude' and 'Longitude' columns
mean_latitude = df_1['latitude'].mean()
mean_longitude = df_1['longitude'].mean()

# %%
# Fill the missing values with their respective mean values
df_1.loc[:, 'latitude'] = df_1['latitude'].fillna(mean_latitude)
df_1.loc[:, 'longitude'] = df_1['longitude'].fillna(mean_longitude)

# %%
df_1[['latitude', 'longitude']].isnull().sum()
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# Outlieres

# %%
# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']

# %%
# Calculate outliers using Z-score
z_scores =df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# %%
# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# %%
# Plot Box Plots to visualize the distribution and outliers
plt.figure(figsize=(12, 8))
df_1[numerical_columns].boxplot()
plt.title("Box Plot of Numerical Columns")
plt.xticks(rotation=90)
plt.show()

# Plot Box Plots separately for each numerical column to focus on individual distributions
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    df_1[[column]].boxplot()
    plt.title(f"Box Plot of {column}")
    plt.show()

# %%
# Remove outliers

# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']

# Calculate Z-scores for each numerical column
z_scores = df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Remove rows with outliers in any numerical column
df_1_no_outliers = df_1[~outliers.any(axis=1)]

# Visualize the distribution of cleaned data with Box Plots
plt.figure(figsize=(12, 8))
df_1_no_outliers = df_1[~outliers.any(axis=1)]
df_1_no_outliers[numerical_columns].boxplot()  # Removed the square brackets here
plt.title("Box Plot of Numerical Columns (After Removing Outliers)")
plt.xticks(rotation=90)
plt.show()

# %%
df_1.shape
# Out:
# (195145, 27)

# %%
df_1['District']
# Out:
# 0        Bargarh
# 1        Bargarh
# 2        Bargarh
# 3        Bargarh
# 4        Bargarh
#           ...
# 13825      Purba
# 13826      Purba
# 13827      Purba
# 13828      Purba
# 13829      Purba
# Name: District, Length: 195145, dtype: object

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195145 entries, 0 to 13829
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NICName                      195145 non-null  object
#  1   MainWorkersTotalPersons      195145 non-null  int64
#  2   MainWorkersTotalMales        195145 non-null  int64
#  3   MainWorkersTotalFemales      195145 non-null  int64
#  4   MainWorkersRuralPersons      195145 non-null  int64
#  5   MainWorkersRuralMales        195145 non-null  int64
#  6   MainWorkersRuralFemales      195145 non-null  int64
#  7   MainWorkersUrbanPersons      195145 non-null  int64
#  8   MainWorkersUrbanMales        195145 non-null  int64
#  9   MainWorkersUrbanFemales      195145 non-null  int64
#  10  MarginalWorkersTotalPersons  195145 non-null  int64
#  11  MarginalWorkersTotalMales    195145 non-null  int64
#  12  MarginalWorkersTotalFemales  195145 non-null  int64
#  13  MarginalWorkersRuralPersons  195145 non-null  int64
#  14  MarginalWorkersRuralMales    195145 non-null  int64
#  15  MarginalWorkersRuralFemales  195145 non-null  int64
#  16  MarginalWorkersUrbanPersons  195145 non-null  int64
#  17  MarginalWorkersUrbanMales    195145 non-null  int64
#  18  MarginalWorkersUrbanFemales  195145 non-null  int64
#  19  State                        195145 non-null  object
#  20  District                     195145 non-null  object
#  21  TotalWorkers                 195145 non-null  int64
#  22  MaleFemaleRatio              195145 non-null  float64
#  23  TotalPopulation              195145 non-null  int32
#  24  WorkersRatio                 195145 non-null  int32
#  25  latitude                     195145 non-null  float64
#  26  longitude                    195145 non-null  float64
# dtypes: float64(3), int32(2), int64(19), object(3)
# memory usage: 40.2+ MB

# %%
df_1.nunique()
# Out:
# NICName                          587
# MainWorkersTotalPersons         8679
# MainWorkersTotalMales           7811
# MainWorkersTotalFemales         3970
# MainWorkersRuralPersons         5767
# MainWorkersRuralMales           5218
# MainWorkersRuralFemales         2694
# MainWorkersUrbanPersons         6561
# MainWorkersUrbanMales           5934
# MainWorkersUrbanFemales         2929
# MarginalWorkersTotalPersons     4208
# MarginalWorkersTotalMales       3181
# MarginalWorkersTotalFemales     2850
# MarginalWorkersRuralPersons     3406
# MarginalWorkersRuralMales       2535
# MarginalWorkersRuralFemales     2379
# MarginalWorkersUrbanPersons     2421
# MarginalWorkersUrbanMales       1951
# MarginalWorkersUrbanFemales     1557
# State                             23
# District                         440
# TotalWorkers                    9451
# MaleFemaleRatio                29974
# TotalPopulation                 9451
# WorkersRatio                       1
# latitude                          34
# longitude                         33
# dtype: int64

# %%
df_1.to_csv("C:/Users/smm/Downloads/newdf.csv", index = False)

# %% [markdown]
# NLP

# %%
# new df_1
df_2 = pd.read_csv("C:/Users/smm/Downloads/newdf.csv")
df_2.head(2)
# Out:
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                   630079
# 1  Crop and animal production, hunting and relate...                    18891
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                 447722                   182357                   482453
# 1                  13846                     5045                    16426
#
#    MainWorkersRuralMales  MainWorkersRuralFemales  MainWorkersUrbanPersons  \
# 0                 337954                   144499                   147626
# 1                  11949                     4477                     2465
#
#    MainWorkersUrbanMales  MainWorkersUrbanFemales  ...  \
# 0                 109768                    37858  ...
# 1                   1897                      568  ...
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales   State  District  \
# 0                      20106                        15694  ODISHA   Bargarh
# 1                        573                          430  ODISHA   Bargarh
#
#    TotalWorkers  MaleFemaleRatio  TotalPopulation  WorkersRatio   latitude  \
# 0       1064141         2.455195          1064141             1  11.667026
# 1         42292         2.744500            42292             1  14.750429
#
#    longitude
# 0  92.735983
# 1  78.570026
#
# [2 rows x 27 columns]

# %%
df_2.columns.tolist()
# Out:
# ['NICName',
#  'MainWorkersTotalPersons',
#  'MainWorkersTotalMales',
#  'MainWorkersTotalFemales',
#  'MainWorkersRuralPersons',
#  'MainWorkersRuralMales',
#  'MainWorkersRuralFemales',
#  'MainWorkersUrbanPersons',
#  'MainWorkersUrbanMales',
#  'MainWorkersUrbanFemales',
#  'MarginalWorkersTotalPersons',
#  'MarginalWorkersTotalMales',
#  'MarginalWorkersTotalFemales',
#  'MarginalWorkersRuralPersons',
#  'MarginalWorkersRuralMales',
#  'MarginalWorkersRuralFemales',
#  'MarginalWorkersUrbanPersons',
#  'MarginalWorkersUrbanMales',
#  'MarginalWorkersUrbanFemales',
#  'State',
#  'District',
#  'TotalWorkers',
#  'MaleFemaleRatio',
#  'TotalPopulation',
#  'WorkersRatio',
#  'latitude',
#  'longitude']

# %%
df_2['NICName'].unique()
# Out:
# array(['Total',
#        'Crop and animal production, hunting and related service activities',
#        'Growing of non-perennial crops',
#        'Growing of cereals (except rice), leguminous crops and oil seeds',
#        'Growing of rice',
#        'Growing of vegetables and melons, roots and tubers',
#        'Growing of sugar cane', 'Growing of tobacco',
#        'Growing of fibre crops', 'Growing of other non-perennial crop',
#        'Growing of perennial crops',
#        'Growing of tropical and subtropical fruits',
#        'Growing of citrus fruits',
#        'Growing of pome fruits and stone fruits',
#        'Growing of other tree and bush fruits and nuts',
#        'Growing of oleaginous fruits', 'Growing of beverage crops',
#        'Growing of spices, aromatic, drug and pharmaceutical crops',
#        'Growing of other perennial crops', 'Plant propagation',
#        'Animal production', 'Raising of cattle and buffaloes',
#        'Raising and breeding of camels and camelids',
#        'Raising of sheep and goats', 'Raising of swine/pigs',
#        'Raising of poultry', 'Raising of other animals', 'Mixed farming',
#        'Support activities to agriculture and post-harvest crop activities',
#        'Support activities for crop production',
#        'Support activities for animal production',
#        'Post-harvest crop activities', 'Seed processing for propagation',
#        'Hunting, trapping and related service activities',
#        'Forestry and logging',
#        'Silviculture and other forestry activities', 'Logging',
#        'Gathering of non-wood forest products',
#        'Support services to forestry', 'Fishing and aquaculture',
#        'Fishing', 'Marine fishing', 'Freash water fishing', 'Aquaculture',
#        'Marine aquaculture', 'Freshwater aquaculture',
#        'Mining of coal and lignite', 'Mining of hard coal',
#        'Mining of lignite',
#        'Extraction of crude petroleum and natural gas',
#        'Extraction of crude petroleum', 'Extraction of natural gas',
#        'Mining of metal ores', 'Mining of iron ores',
#        'Mining of non-ferrous metal ores',
#        'Mining of uranium and thorium ores',
#        'Mining of other non-ferrous metal ores',
#        'Other mining and quarrying', 'Quarrying of stone, sand and clay',
#        'Mining and quarrying n.e.c.',
#        'Mining of chemical and fertilizer minerals',
#        'Extraction and agglomeration of peat', 'Extraction of salt',
#        'Other mining and quarrying n.e.c.',
#        'Mining support service activities',
#        'Support activities for petroleum and natural gas mining',
#        'Support activities for other mining and quarrying',
#        'Manufacture of food products',
#        'Processing and preserving of meat',
#        'Processing and preserving of fish, crustaceans and molluscs',
#        'Processing and preserving of fish, crustaceans and molluscs and',
#        'Processing and preserving of fruit and vegetables',
#        'Manufacture of vegetable and animal oils and fats',
#        'Manufacture of dairy products',
#        'Manufacture of grain mill products, starches and starch products',
#        'Manufacture of grain mill products',
#        'Manufacture of starches and starch products',
#        'Manufacture of other food products',
#        'Manufacture of bakery products', 'Manufacture of sugar',
#        'Manufacture of cocoa, chocolate and sugar confectionery',
#        'Manufacture of macaroni, noodles, couscous and similar farinaceous',
#        'Manufacture of prepared meals and dishes',
#        'Manufacture of other food products n.e.c.',
#        'Manufacture of prepared animal feeds', 'Manufacture of beverages',
#        'Distilling, rectifying and blending of spirits; ethyl alcohol production',
#        'Manufacture of wines', 'Manufacture of malt liquors and malt',
#        'Manufacture of soft drinks; production of mineral waters and other',
#        'Manufacture of tobacco products', 'Manufacture of textiles',
#        'Spinning, weaving and finishing of textiles',
#        'Preparation and spinning of textile fibres',
#        'Weaving of textiles', 'Finishing of textiles',
#        'Manufacture of other textiles',
#        'Manufacture of knitted and crocheted fabrics',
#        'Manufacture of made-up textile articles, except apparel',
#        'Manufacture of carpets and rugs',
#        'Manufacture of cordage, rope, twine and netting',
#        'Manufacture of other textiles n.e.c.',
#        'Manufacture of wearing apparel',
#        'Manufacture of wearing apparel, except fur apparel',
#        'Manufacture of articles of fur',
#        'Manufacture of leather and related products',
#        'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery',
#        'Manufacture of luggage, handbags and the like, saddlery and harness',
#        'Manufacture of footwear',
#        'Manufacture of wood and products of wood and cork, except furniture;',
#        'Sawmilling and planing of wood',
#        'Saw milling and planing of wood',
#        'Manufacture of products of wood, cork, straw and plaiting materials',
#        'Manufacture of veneer sheets; manufacture of plywood, laminboard,',
#        'Manufacture of builders\x92 carpentry and joinery',
#        'Manufacture of wooden containers',
#        'Manufacture of other products of wood; manufacture of articles of cork,',
#        'Manufacture of paper and paper products',
#        'Manufacture of pulp, paper and paperboard',
#        'Manufacture of corrugated paper and paperboard and containers of',
#        'Manufacture of other articles of paper and paperboard',
#        'Printing and reproduction of recorded media',
#        'Printing and service activities related to printing', 'Printing',
#        'Service activities related to printing',
#        'Manufacture of coke and refined petroleum products',
#        'Manufacture of coke oven products',
#        'Manufacture of refined petroleum products',
#        'Manufacture of chemicals and chemical products',
#        'Manufacture of basic chemicals, fertilizer and nitrogen compounds, plastics',
#        'Manufacture of basic chemicals',
#        'Manufacture of fertilizers and nitrogen compounds',
#        'Manufacture of plastics and synthetic rubber in primary forms',
#        'Manufacture of other chemical products',
#        'Manufacture of pesticides and other agrochemical products',
#        'Manufacture of paints, varnishes and similar coatings, printing ink and',
#        'Manufacture of soap and detergents, cleaning and polishing preparations,',
#        'Manufacture of other chemical products n.e.c.',
#        'Manufacture of pharmaceuticals, medicinal chemical and botanical products',
#        'Manufacture of pharmaceuticals, medicinal chemical and botanical',
#        'Manufacture of rubber and plastics products',
#        'Manufacture of rubber products',
#        'Manufacture of rubber tyres and tubes; retreading and rebuilding of',
#        'Manufacture of other rubber products',
#        'Manufacture of plastics products',
#        'Manufacture of other non-metallic mineral products',
#        'Manufacture of glass and glass products',
#        'Manufacture of non-metallic mineral products n.e.c.',
#        'Manufacture of refractory products',
#        'Manufacture of clay building materials',
#        'Manufacture of other porcelain and ceramic products',
#        'Manufacture of cement, lime and plaster',
#        'Manufacture of articles of concrete, cement and plaster',
#        'Cutting, shaping and finishing of stone',
#        'Manufacture of other non-metallic mineral products n.e.c.',
#        'Manufacture of basic metals',
#        'Manufacture of basic iron and steel',
#        'Manufacture of basic precious and other non-ferrous metals',
#        'Casting of metals', 'Casting of iron and steel',
#        'Casting of non-ferrous metals',
#        'Manufacture of fabricated metal products, except machinery and equipment',
#        'Manufacture of structural metal products, tanks, reservoirs and steam',
#        'Manufacture of structural metal products',
#        'Manufacture of tanks, reservoirs and containers of metal',
#        'Manufacture of steam generators, except central heating hot water',
#        'Manufacture of weapons and ammunition',
#        'Manufacture of other fabricated metal products; metalworking service',
#        'Forging, pressing, stamping and roll-forming of metal; powder',
#        'Machining; treatment and coating of metals',
#        'Manufacture of cutlery, hand tools and general hardware',
#        'Manufacture of other fabricated metal products n.e.c.',
#        'Manufacture of computer, electronic and optical products',
#        'Manufacture of electronic components',
#        'Manufacture of computers and peripheral equipment',
#        'Manufacture of communication equipment',
#        'Manufacture of consumer electronics',
#        'Manufacture of measuring, testing, navigating and control equipment;',
#        'Manufacture of measuring, testing, navigating and control equipment',
#        'Manufacture of watches and clocks',
#        'Manufacture of electrical equipment',
#        'Manufacture of electric motors, generators, transformers and electricity',
#        'Manufacture of batteries and accumulators',
#        'Manufacture of wiring and wiring devices',
#        'Manufacture of other electronic and electric wires and cables',
#        'Manufacture of wiring devices',
#        'Manufacture of electric lighting equipment',
#        'Manufacture of domestic appliances',
#        'Manufacture of machinery and equipment n.e.c.',
#        'Manufacture of general purpose machinery',
#        'Manufacture of engines and turbines, except aircraft, vehicle and cycle',
#        'Manufacture of other pumps, compressors, taps and valves',
#        'Manufacture of lifting and handling equipment',
#        'Manufacture of power-driven hand tools',
#        'Manufacture of other general-purpose machinery',
#        'Manufacture of special-purpose machinery',
#        'Manufacture of agricultural and forestry machinery',
#        'Manufacture of metal-forming machinery and machine tools',
#        'Manufacture of machinery for metallurgy',
#        'Manufacture of machinery for mining, quarrying and construction',
#        'Manufacture of machinery for food, beverage and tobacco processing',
#        'Manufacture of machinery for textile, apparel and leather production',
#        'Manufacture of other special-purpose machinery',
#        'Manufacture of motor vehicles, trailers and semi-trailers',
#        'Manufacture of motor vehicles',
#        'Manufacture of bodies (coachwork) for motor vehicles; manufacture of',
#        'Manufacture of bodies (coachwork) for motor vehicles; manufacture of trailers and semi-trailers',
#        'Manufacture of parts and accessories for motor vehicles',
#        'Manufacture of other transport equipment',
#        'Building of ships and boats',
#        'Building of ships and floating structures',
#        'Building of pleasure and sporting boats',
#        'Manufacture of railway locomotives and rolling stock',
#        'Manufacture of air and spacecraft and related machinery',
#        'Manufacture of transport equipment n.e.c.',
#        'Manufacture of motorcycles',
#        'Manufacture of bicycles and invalid carriages',
#        'Manufacture of other transport equipment n.e.c.',
#        'Manufacture of furniture', 'Other manufacturing',
#        'Manufacture of jewellery, bijouterie and related articles',
#        'Manufacture of jewellery and related articles',
#        'Manufacture of imitation jewellery and related articles',
#        'Manufacture of musical instruments',
#        'Manufacture of games and toys', 'Other manufacturing n.e.c.',
#        'Repair and installation of machinery and equipment',
#        'Repair of fabricated metal products, machinery and equipment',
#        'Repair of fabricated metal products', 'Repair of machinery',
#        'Repair of electronic and optical equipment',
#        'Repair of electrical equipment',
#        'Repair of transport equipment, except motor vehicles',
#        'Repair of other equipment',
#        'Installation of industrial machinery and equipment',
#        'Electricity, gas, steam and air conditioning supply',
#        'Electric power generation, transmission and distribution',
#        'Manufacture of gas; distribution of gaseous fuels through mains',
#        'Steam and air conditioning supply',
#        'Water collection, treatment and supply', 'Sewerage',
#        'Waste collection, treatment and disposal activities; materials recovery',
#        'Waste collection', 'Collection of non-hazardous waste',
#        'Collection of hazardous waste', 'Waste treatment and disposal',
#        'Treatment and disposal of non-hazardous waste',
#        'Treatment and disposal of hazardous waste',
#        'Remediation activities and other waste management services',
#        'Construction of buildings', 'Civil engineering',
#        'Construction of roads and railways',
#        'Construction roads and railways',
#        'Construction of utility projects',
#        'Construction of other civil engineering projects',
#        'Specialized construction activities',
#        'Demolition and site preparation', 'Site preparation',
#        'Electrical, plumbing and other construction installation activities',
#        'Electrical installation',
#        'Plumbing, heat and air-conditioning installation',
#        'Other construction installation',
#        'Building completion and finishing',
#        'Other specialized construction activities',
#        'Wholesale and retail trade and repair of motor vehicles and motorcycles',
#        'Sale of motor vehicles',
#        'Maintenance and repair of motor vehicles',
#        'Sale of motor vehicle parts and accessories',
#        'Sale, maintenance and repair of motorcycles and related parts and',
#        'Wholesale trade, except of motor vehicles and motorcycles',
#        'Wholesale on a fee or contract basis',
#        'Wholesale of agricultural raw materials and live animals',
#        'Wholesale of food, beverages and tobacco',
#        'Wholesale of household goods',
#        'Wholesale of textiles, clothing and footwear',
#        'Wholesale of other household goods',
#        'Wholesale of machinery, equipment and supplies',
#        'Wholesale of computers, computer peripheral equipment and software',
#        'Wholesale of electronic and telecommunications equipment and parts',
#        'Wholesale of agricultural machinery, equipment and supplies',
#        'Wholesale of other machinery and equipment',
#        'Other specialized wholesale',
#        'Wholesale of solid, liquid and gaseous fuels and related products',
#        'Wholesale of construction materials, hardware, plumbing and heating',
#        'Wholesale of waste and scrap and other products n.e.c.',
#        'Non-specialized wholesale trade',
#        'Retail trade, except of motor vehicles and motorcycles',
#        'Retail sale in non-specialized stores',
#        'Retail sale in non-specialized stores with food, beverages or tobacco',
#        'Other retail sale in non-specialized stores',
#        'Retail sale of food, beverages and tobacco in specialized stores',
#        'Retail sale of food in specialized stores',
#        'Retail sale of beverages in specialized stores',
#        'Retail sale of tobacco products in specialized stores',
#        'Retail sale of automotive fuel in specialized stores',
#        'Retail sale of information and communications equipment in specialized',
#        'Retail sale of computers, peripheral units, software and',
#        'Retail sale of audio and video equipment in specialized stores',
#        'Retail sale of other household equipment in specialized stores',
#        'Retail sale of textiles in specialized stores',
#        'Retail sale of hardware, paints and glass in specialized stores',
#        'Retail sale of carpets, rugs, wall and floor coverings in specialized',
#        'Retail sale of electrical household appliances, furniture, lighting',
#        'Retail sale of cultural and recreation goods in specialized stores',
#        'Retail sale of books, newspapers and stationary in specialized stores',
#        'Retail sale of music and video recordings in specialized stores',
#        'Retail sale of games and toys in specialized stores',
#        'Retail sale of other goods in specialized stores',
#        'Retail sale of clothing, footwear and leather articles in specialized',
#        'Retail sale of pharmaceutical and medical goods, cosmetic and toilet',
#        'Other retail sale of new goods in specialized stores',
#        'Retail sale of second-hand goods',
#        'Retail sale via stalls and markets',
#        'Retail sale via stalls and markets of food, beverages and tobacco',
#        'Retail sale via stalls and markets of textiles, clothing and footwear',
#        'Retail sale via stalls and markets of other goods',
#        'Retail trade not in stores, stalls or markets',
#        'Retail sale via mail order houses or via Internet',
#        'Other retail sale not in stores, stalls or markets',
#        'Land transport and transport via pipelines',
#        'Transport via railways', 'Passenger rail transport',
#        'Freight rail transport', 'Other land transport',
#        'Urban or suburban passenger land transport',
#        'Other passenger land transport', 'Freight transport by road',
#        'Transport via pipeline', 'Water transport',
#        'Sea and coastal water transport',
#        'Sea and coastal passenger water transport',
#        'Sea and coastal freight water transport',
#        'Inland water transport', 'Inland passenger water transport',
#        'Air transport', 'Passenger air transport',
#        'Freight air transport',
#        'Warehousing and support activities for transportation',
#        'Warehousing and storage', 'Support activities for transportation',
#        'Service activities incidental to land transportation',
#        'Service activities incidental to water transportation',
#        'Service activities incidental to air transportation',
#        'Cargo handling', 'Other transportation support activities',
#        'Postal and courier activities', 'Postal activities',
#        'Courier activities', 'Accommodation',
#        'Short term accommodation activities', 'Other accommodation',
#        'Food and beverage service activities',
#        'Restaurants and mobile food service activities',
#        'Event catering and other food service activities',
#        'Event catering', 'Other food service activities',
#        'Beverage serving activities', 'Publishing activities',
#        'Publishing of books, periodicals and other publishing activities',
#        'Book publishing',
#        'Publishing of newspapers, journals and periodicals',
#        'Other publishing activities', 'Software publishing',
#        'Motion picture, video and television programme production, sound recording',
#        'Motion picture, video and television programme activities',
#        'Motion picture, video and television programme production activities',
#        'Motion picture, video and television programme post-production',
#        'Motion picture, video and television programme distribution activities',
#        'Motion picture projection activities',
#        'Sound recording and music publishing activities',
#        'Sound recording and music publishing activitiesT',
#        'Broadcasting and programming activities', 'Radio broadcasting',
#        'Television programming and broadcasting activities',
#        'Telecommunications', 'Wired telecommunications activities',
#        'Wireless telecommunications activities',
#        'Satellite telecommunications activities',
#        'Other telecommunications activities',
#        'Computer programming, consultancy and related activities',
#        'Computer programming activities',
#        'Computer consultancy and computer facilities management activities',
#        'Other information technology and computer service activities',
#        'Information service activities',
#        'Data processing, hosting and related activities; web portals',
#        'Data processing, hosting and related activities',
#        'Other information service activities', 'News agency activities',
#        'Other information service activities n.e.c.',
#        'Financial service activities, except insurance and pension funding',
#        'Monetary intermediation', 'Central banking',
#        'Other monetary intermediation', 'Activities of holding companies',
#        'Trusts, funds and other financial vehicles',
#        'Other financial service activities, except insurance and pension funding',
#        'Financial leasing', 'Other credit granting',
#        'Insurance, reinsurance and pension funding, except compulsory social',
#        'Insurance', 'Life insurance', 'Non-life insurance',
#        'Pension funding', 'Other financial activities',
#        'Activities auxiliary to financial service activities, except insurance and',
#        'Administration of financial markets',
#        'Activities auxiliary to financial service activities n.e.c.',
#        'Activities auxiliary to insurance and pension funding',
#        'Activities of insurance agents and brokers',
#        'Other activities auxiliary to insurance and pension funding',
#        'Fund management activities', 'Real estate activities',
#        'Real estate activities with own or leased property',
#        'Real estate activities on a fee or contract basis',
#        'Legal and accounting activities', 'Legal activities',
#        'Accounting, bookkeeping and auditing activities; tax consultancy',
#        'Architecture and engineering activities; technical testing and analysis',
#        'Architectural and engineering activities and related technical consultancy',
#        'Architectural and engineering activities and related technical',
#        'Technical testing and analysis',
#        'Scientific research and development',
#        'Research and experimental development on natural sciences and',
#        'Research and experimental development on social sciences and humanities',
#        'Research and experimental development on social sciences and',
#        'Advertising and market research', 'Advertising',
#        'Market research and public opinion polling',
#        'Other professional, scientific and technical activities',
#        'Specialized design activities', 'Photographic activities',
#        'Other professional, scientific and technical activities n.e.c.',
#        'Veterinary activities', 'Rental and leasing activities',
#        'Renting and leasing of motor vehicles',
#        'Renting and leasing of personal and household goods',
#        'Renting of video tapes and disks',
#        'Renting and leasing of other personal and household goods n.e.c.',
#        'Renting and leasing of other machinery, equipment and tangible goods',
#        'Employment activities',
#        'Activities of employment placement agencies',
#        'Temporary employment agency activities',
#        'Human resources provision and management of human resources functions',
#        'Human resources provision and management of human resources',
#        'Travel agency, tour operator and other reservation service activities',
#        'Travel agency and tour operator activities',
#        'Travel agency activities',
#        'Security and investigation activities',
#        'Private security activities',
#        'Security systems service activities', 'Investigation activities',
#        'Services to buildings and landscape activities',
#        'Combined facilities support activities', 'Cleaning activities',
#        'General cleaning of buildings',
#        'Other building and industrial cleaning activities',
#        'Landscape care and maintenance service activities',
#        'Office administrative, office support and other business support activities',
#        'Office administrative and support activities',
#        'Combined office administrative service activities',
#        'Photocopying, document preparation and other specialized office',
#        'Business support service activities n.e.c.',
#        'Activities of collection agencies and credit bureaus',
#        'Packaging activities',
#        'Other business support service activities n.e.c.',
#        'Public administration and defence; compulsory social security',
#        'Administration of the State and the economic and social policy of the',
#        'General public administration activities',
#        'Regulation of the activities of providing health care, education, cultural',
#        'Regulation of and contribution to more efficient operation of',
#        'Provision of services to the community as a whole',
#        'Defence activities', 'Public order and safety activities',
#        'Compulsory social security activities', 'Education',
#        'Primary education', 'Secondary education',
#        'General secondary education',
#        'Technical and vocational secondary education', 'Higher education',
#        'Other education', 'Sports and recreation education',
#        'Cultural education', 'Other education n.e.c.',
#        'Educational support services', 'Human health activities',
#        'Hospital activities', 'Medical and dental practice activities',
#        'Other human health activities', 'Residential care activities',
#        'Nursing care facilities',
#        'Residential care activities for mental retardation, mental health and substance',
#        'Residential care activities for mental retardation, mental health and',
#        'Residential care activities for the elderly and disabled',
#        'Other residential care activities n.e.c.',
#        'Social work activities without accommodation',
#        'Social work activities without accommodation for the elderly and disabled',
#        'Social work activities without accommodation for the elderly and',
#        'Other social work activities without accommodation n.e.c.',
#        'Creative, arts and entertainment activities',
#        'Dramatic arts, music and other arts activities',
#        'Libraries, archives, museums and other cultural activities',
#        'Library and archives activities',
#        'Museums activities and operation of historical sites and buildings',
#        'Botanical and zoological gardens and nature reserves activities',
#        'Gambling and betting activities',
#        'Sports activities and amusement and recreation activities',
#        'Sports activities', 'Operation of sports facilities',
#        'Other sports activities',
#        'Other amusement and recreation activities',
#        'Activities of amusement parks and theme parks',
#        'Other amusement and recreation activities n.e.c.',
#        'Activities of membership organizations',
#        'Activities of business, employers and professional membership',
#        'Activities of business and employers membership organizations',
#        'Activities of professional membership organizations',
#        'Activities of trade unions',
#        'Activities of other membership organizations',
#        'Activities of religious organizations',
#        'Activities of political organizations',
#        'Activities of other membership organizations n.e.c.',
#        'Repair of computers and personal and household goods',
#        'Repair of computers and communication equipment',
#        'Repair of computers and peripheral equipment',
#        'Repair of communication equipment',
#        'Repair of personal and household goods',
#        'Repair of consumer electronics',
#        'Repair of household appliances and home and garden equipment',
#        'Repair of footwear and leather goods',
#        'Repair of furniture and home furnishings',
#        'Repair of personal and household goods, n.e.c.',
#        'Other personal service activities',
#        'Washing and (dry-) cleaning of textile and fur products',
#        'Hairdressing and other beauty treatment',
#        'Other personal service activities n.e.c.',
#        'Activities of households as employers of domestic personnel',
#        'Undifferentiated goods- and services-producing activities of private',
#        'Undifferentiated goods-producing activities of private households for own',
#        'Undifferentiated service-producing activities of private households for own',
#        'Activities of extraterritorial organizations and bodies', 'Blank',
#        'Incomplete description/ Wrongly Classifed',
#        'Raising of horses and other equines',
#        'Manufacture of knitted and crocheted apparel',
#        'Manufacture of sports goods', 'Demolition',
#        'Retail sale of sporting equipment in specialized stores',
#        'Inland freight water transport', 'Web portals',
#        'Activities of head offices; management consultancy activities',
#        'Activities of head offices', 'Activities of call centres',
#        'Organization of conventions and trade shows', 'Foreign affairs',
#        'Activities of sports clubs', 'Funeral and related activities',
#        'Tanning and dressing of leather; dressing and dyeing of fur',
#        'Manufacture of office machinery and equipment',
#        'Management consultancy activities', 'Tour operator activities',
#        'Manufacture of bearings, gears, gearing and driving elements',
#        'Manufacture of medical and dental instruments and supplies',
#        'Camping grounds, recreational vehicle parks and trailer parks',
#        'Manufacture of other electrical equipment',
#        'Manufacture of military fighting vehicles',
#        'Manufacture of fluid power equipment',
#        'Security and commodity contracts brokerage', 'Blank etc.',
#        'Manufacture of man-made fibres',
#        'Manufacture of magnetic and optical media',
#        'Manufacture of optical instruments and equipment',
#        'Growing of grapes', 'Reproduction of recorded media',
#        'Manufacture of irradiation, electromedical and electrotherapeutic',
#        'Manufacture of ovens, furnaces and furnace burners',
#        'Wholesale of metals and metal ores',
#        'Publishing of directories and mailing lists',
#        'Renting and leasing of recreational and sports goods',
#        'Leasing of nonfinancial intangible assets',
#        'Other reservation service activities',
#        'Other reservation service and related activities',
#        'Manufacture of fibre optic cables for data transmission or live',
#        'Manufacture of anti-sprouting products', 'Reinsurance',
#        'Risk and damage evaluation', 'Materials recovery'], dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
from nltk.probability import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\smm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\smm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_2.dtypes
# Out:
# NICName                         object
# MainWorkersTotalPersons          int64
# MainWorkersTotalMales            int64
# MainWorkersTotalFemales          int64
# MainWorkersRuralPersons          int64
# MainWorkersRuralMales            int64
# MainWorkersRuralFemales          int64
# MainWorkersUrbanPersons          int64
# MainWorkersUrbanMales            int64
# MainWorkersUrbanFemales          int64
# MarginalWorkersTotalPersons      int64
# MarginalWorkersTotalMales        int64
# MarginalWorkersTotalFemales      int64
# MarginalWorkersRuralPersons      int64
# MarginalWorkersRuralMales        int64
# MarginalWorkersRuralFemales      int64
# MarginalWorkersUrbanPersons      int64
# MarginalWorkersUrbanMales        int64
# MarginalWorkersUrbanFemales      int64
# State                           object
# District                        object
# TotalWorkers                     int64
# MaleFemaleRatio                float64
# TotalPopulation                  int64
# WorkersRatio                     int64
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
from gensim.models import Word2Vec

# Assuming 'cleaned_tokens' is the column containing tokenized text
sentences = df_2['NICName'].tolist()

# Train Word2Vec model
model = Word2Vec(df_2['NICName'], vector_size=100, window=5, min_count=1, workers=4)

# Save the Word2Vec model
model.save("word2vec_model")

# You can use the trained Word2Vec model to get word vectors
word_to_check = 'uranium'
word_vector = model.wv[word_to_check]

# %%
pip install gensim
# Out:
# Collecting gensim
#   Obtaining dependency information for gensim from https://files.pythonhosted.org/packages/ad/97/b8253236dfedb9094f4273393a3fd03997da81f27f15822e56128da894ae/gensim-4.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading gensim-4.3.2-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.11.3)
# Collecting smart-open>=1.8.1 (from gensim)
#   Obtaining dependency information for smart-open>=1.8.1 from https://files.pythonhosted.org/packages/ad/08/dcd19850b79f72e3717c98b2088f8a24b549b29ce66849cd6b7f44679683/smart_open-7.0.1-py3-none-any.whl.metadata
#   Downloading smart_open-7.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Obtaining dependency information for wrapt from https://files.pythonhosted.org/packages/cf/c3/0084351951d9579ae83a3d9e38c140371e4c6b038136909235079f2e6e78/wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Downloading gensim-4.3.2-cp311-cp311-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.0 MB 9.6 MB/s eta 0:00:03
#    - -------------------------------------- 1.1/24.0 MB 13.7 MB/s eta 0:00:02
#    - -------------------------------------- 1.2/24.0 MB 8.4 MB/s eta 0:00:03
#    -- ------------------------------------- 1.3/24.0 MB 7.7 MB/s eta 0:00:03
#    -- ------------------------------------- 1.5/24.0 MB 6.8 MB/s eta 0:00:04
#    -- ------------------------------------- 1.6/24.0 MB 6.1 MB/s eta 0:00:04
#    -- ------------------------------------- 1.8/24.0 MB 5.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.9/24.0 MB 5.4 MB/s eta 0:00:05
#    --- ------------------------------------ 2.0/24.0 MB 4.9 MB/s eta 0:00:05
#    --- ------------------------------------ 2.2/24.0 MB 4.7 MB/s eta 0:00:05
#    --- ------------------------------------ 2.3/24.0 MB 4.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.5/24.0 MB 4.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.6/24.0 MB 4.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.7/24.0 MB 4.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.9/24.0 MB 4.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.0/24.0 MB 4.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/24.0 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/24.0 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/24.0 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/24.0 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.1/24.0 MB 4.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.2/24.0 MB 3.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.3/24.0 MB 3.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.6/24.0 MB 3.2 MB/s eta 0:00:07
#    ------ --------------------------------- 3.8/24.0 MB 3.3 MB/s eta 0:00:07
#    ------ --------------------------------- 4.0/24.0 MB 3.3 MB/s eta 0:00:06
#    ------- -------------------------------- 4.3/24.0 MB 3.4 MB/s eta 0:00:06
#    ------- -------------------------------- 4.6/24.0 MB 3.5 MB/s eta 0:00:06
#    -------- ------------------------------- 4.9/24.0 MB 3.7 MB/s eta 0:00:06
#    -------- ------------------------------- 5.0/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.0 MB 3.6 MB/s eta 0:00:06
#    -------- ------------------------------- 5.3/24.0 MB 3.1 MB/s eta 0:00:07
#    --------- ------------------------------ 5.4/24.0 MB 3.1 MB/s eta 0:00:06
#    --------- ------------------------------ 5.6/24.0 MB 3.1 MB/s eta 0:00:06
#    --------- ------------------------------ 5.8/24.0 MB 3.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.0/24.0 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.3/24.0 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.5/24.0 MB 3.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.8/24.0 MB 3.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.1/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 7.3/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 7.4/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 7.5/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 7.6/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 7.8/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------- -------------------------- 8.0/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------- -------------------------- 8.1/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------- -------------------------- 8.3/24.0 MB 3.4 MB/s eta 0:00:05
#    ------------- -------------------------- 8.4/24.0 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.5/24.0 MB 3.4 MB/s eta 0:00:05
#    -------------- ------------------------- 8.7/24.0 MB 3.4 MB/s eta 0:00:05
#    -------------- ------------------------- 8.8/24.0 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.9/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.0/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.2/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.3/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.4/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.4/24.0 MB 3.3 MB/s eta 0:00:05
#    --------------- ------------------------ 9.5/24.0 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.6/24.0 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.8/24.0 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.0/24.0 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.2/24.0 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.5/24.0 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.7/24.0 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.8/24.0 MB 3.2 MB/s eta 0:00:05
#    ------------------ --------------------- 10.9/24.0 MB 3.1 MB/s eta 0:00:05
#    ------------------ --------------------- 11.1/24.0 MB 3.1 MB/s eta 0:00:05
#    ------------------ --------------------- 11.2/24.0 MB 3.1 MB/s eta 0:00:05
#    ------------------ --------------------- 11.3/24.0 MB 3.0 MB/s eta 0:00:05
#    ------------------ --------------------- 11.4/24.0 MB 3.0 MB/s eta 0:00:05
#    ------------------- -------------------- 11.6/24.0 MB 3.0 MB/s eta 0:00:05
#    ------------------- -------------------- 11.7/24.0 MB 3.0 MB/s eta 0:00:05
#    ------------------- -------------------- 11.9/24.0 MB 3.0 MB/s eta 0:00:05
#    -------------------- ------------------- 12.1/24.0 MB 3.0 MB/s eta 0:00:04
#    -------------------- ------------------- 12.2/24.0 MB 3.1 MB/s eta 0:00:04
#    -------------------- ------------------- 12.3/24.0 MB 3.0 MB/s eta 0:00:04
#    -------------------- ------------------- 12.5/24.0 MB 3.0 MB/s eta 0:00:04
#    -------------------- ------------------- 12.6/24.0 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 12.7/24.0 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 12.9/24.0 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 13.1/24.0 MB 3.1 MB/s eta 0:00:04
#    --------------------- ------------------ 13.2/24.0 MB 3.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.3/24.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.4/24.0 MB 3.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.6/24.0 MB 3.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.7/24.0 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 13.9/24.0 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.0/24.0 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.2/24.0 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.3/24.0 MB 3.2 MB/s eta 0:00:04
#    ------------------------ --------------- 14.4/24.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------ --------------- 14.6/24.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------ --------------- 14.7/24.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------ --------------- 14.9/24.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------- -------------- 15.0/24.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------- -------------- 15.2/24.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------- -------------- 15.3/24.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------- -------------- 15.4/24.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------- -------------- 15.5/24.0 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 15.7/24.0 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 15.9/24.0 MB 3.3 MB/s eta 0:00:03
#    -------------------------- ------------- 16.0/24.0 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 16.1/24.0 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.3/24.0 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.4/24.0 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.5/24.0 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.7/24.0 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 16.9/24.0 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.1/24.0 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.3/24.0 MB 3.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.4/24.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.6/24.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.7/24.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.9/24.0 MB 3.1 MB/s eta 0:00:02
#    ------------------------------ --------- 18.1/24.0 MB 3.1 MB/s eta 0:00:02
#    ------------------------------ --------- 18.1/24.0 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 18.3/24.0 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 18.5/24.0 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 18.6/24.0 MB 3.0 MB/s eta 0:00:02
#    ------------------------------- -------- 18.9/24.0 MB 3.0 MB/s eta 0:00:02
#    ------------------------------- -------- 19.0/24.0 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 19.2/24.0 MB 3.0 MB/s eta 0:00:02
#    -------------------------------- ------- 19.4/24.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 19.5/24.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 19.6/24.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 19.7/24.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/24.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 20.1/24.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 20.2/24.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 20.3/24.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 20.5/24.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 20.6/24.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 20.7/24.0 MB 3.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 20.9/24.0 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/24.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.2/24.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.3/24.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.4/24.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.6/24.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 21.7/24.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 21.9/24.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 22.0/24.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 22.2/24.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.3/24.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.4/24.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.6/24.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.7/24.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 22.9/24.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.0/24.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  23.4/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  23.7/24.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  23.8/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  24.0/24.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 2.9 MB/s eta 0:00:00
# Downloading smart_open-7.0.1-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl (37 kB)
# Installing collected packages: wrapt, smart-open, gensim
# Successfully installed gensim-4.3.2 smart-open-7.0.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_2['NICName'] = df_2['NICName'].astype(str)

def clean_and_tokenize(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Tokenization
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    return tokens

# Apply the function to your textual data
df_2['NICName'] = df_2['NICName'].apply(clean_and_tokenize)

# %%
from gensim.models import Word2Vec

# Assuming 'cleaned_tokens' is the column containing tokenized text
sentences = df_2['NICName'].tolist()

# Train Word2Vec model
model = Word2Vec(df_2['NICName'], vector_size=100, window=5, min_count=1, workers=4)

# Save the Word2Vec model
model.save("word2vec_model")

# You can use the trained Word2Vec model to get word vectors
word_to_check = 'uranium'
word_vector = model.wv[word_to_check]

# %%
word_vector
# Out:
# array([-0.03989544,  0.02258973, -0.05414164,  0.02076888, -0.00966616,
#        -0.08719587, -0.06602816,  0.09244988, -0.15094279,  0.04333479,
#        -0.00740529, -0.02912751,  0.00998375,  0.08376962,  0.00663529,
#        -0.0597913 ,  0.07282671, -0.10140558, -0.05663218, -0.08647749,
#         0.03684687, -0.02825881,  0.06103439, -0.02229466,  0.00352254,
#         0.04756027, -0.04469986, -0.05664306, -0.0188927 ,  0.08541165,
#         0.0520913 ,  0.01166012, -0.01044333, -0.100541  , -0.0450586 ,
#         0.06691219, -0.04412783,  0.0140539 , -0.03718736, -0.12481788,
#        -0.01292965, -0.07743223,  0.00383607, -0.00485605,  0.03924547,
#         0.01414823, -0.06950681,  0.03762588,  0.03355257, -0.00755376,
#        -0.00341627, -0.01093458,  0.00360113, -0.01137198,  0.00356721,
#        -0.05871294, -0.00545863,  0.0538268 , -0.00830287,  0.06912626,
#         0.07940106, -0.08449429,  0.0240934 , -0.06296432, -0.04384843,
#         0.05208935,  0.03637373,  0.03601137, -0.07827473,  0.02206466,
#         0.01742546,  0.01734076, -0.04991809,  0.0218313 ,  0.05174937,
#         0.0292193 , -0.02046974, -0.02586197, -0.0779902 ,  0.06218161,
#        -0.03688852, -0.02687403, -0.06432248, -0.01153904,  0.02195453,
#        -0.00926344,  0.0267301 ,  0.06718227, -0.00097347, -0.04086786,
#         0.11821774,  0.03908771, -0.01439251, -0.00263599,  0.06254873,
#         0.04633323,  0.10196442, -0.08689298,  0.04821592, -0.04772639],
#       dtype=float32)

# %%
# Assuming 'model' is your Word2Vec model
print(model)
# Out:
# Word2Vec<vocab=707, vector_size=100, alpha=0.025>

# %%
# Calculate word frequencies
all_tokens = [token for tokens_list in df_2['NICName'] for token in tokens_list]
freq_dist = FreqDist(all_tokens)

# Visualize word frequencies using a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dist)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Create a sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Convert the list to a string
df_2['NICName_str'] = df_2['NICName'].apply(lambda x: ' '.join(map(str, x)))

# Apply sentiment analysis to the new string column
df_2['sentiment_score'] = df_2['NICName_str'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
# Assuming you have already trained and saved the Word2Vec model
# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'workers' is in the vocabulary
word_to_check = 'grapes' 

word_vector = loaded_model.wv[word_to_check]

# # Get the vocabulary of the model
# vocabulary = loaded_model.wv.key_to_index

# # Print the vocabulary
# print("Vocabulary:", vocabulary)

# %%
# Check model


from gensim.models import Word2Vec

# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'MarginalWorkersRuralMales' is in the vocabulary
word_to_check = 'MarginalWorkersRuralMales'

if word_to_check in loaded_model.wv:
    print(f"The word '{word_to_check}' is present in the Word2Vec model's vocabulary.")
    # Retrieve the word vector if needed
    word_vector = loaded_model.wv[word_to_check]
    print("Word Vector:", word_vector)
else:
    print(f"The word '{word_to_check}' is not present in the Word2Vec model's vocabulary.")
# Out:
# The word 'MarginalWorkersRuralMales' is not present in the Word2Vec model's vocabulary.

# %%
# model.to_csv("model_HRM.csv", index = False)

# %%
# Get the vocabulary of the Word2Vec model
vocabulary = loaded_model.wv.key_to_index

# Print the first 10 words in the vocabulary
print(list(vocabulary.keys())[:10])
# Out:
# ['activities', 'manufacture', 'products', 'sale', 'retail', 'service', 'nec', 'equipment', 'specialized', 'stores']

# %%
df_2.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude', 'NICName_str',
#        'sentiment_score'],
#       dtype='object')

# %%
df2.to_csv("C:/Users/smm/Downloads/final_HR.csv", index = False)

# %%
model = pd.read_csv("C:/Users/smm/Downloads/ResaleFlatPrices_combaine.csv")
model
# Out:
#                                                   NICName  \
# 0                                                   Total
# 1       Crop and animal production, hunting and relate...
# 2                          Growing of non-perennial crops
# 3       Growing of cereals (except rice), leguminous c...
# 4                                         Growing of rice
# ...                                                   ...
# 195140  Activities of extraterritorial organizations a...
# 195141                                              Blank
# 195142                                              Blank
# 195143          Incomplete description/ Wrongly Classifed
# 195144          Incomplete description/ Wrongly Classifed
#
#         MainWorkersTotalPersons  MainWorkersTotalMales  \
# 0                        630079                 447722
# 1                         18891                  13846
# 2                           253                    191
# 3                            33                     31
# 4                            40                     28
# ...                         ...                    ...
# 195140                       18                     12
# 195141                     8244                   5866
# 195142                     8244                   5866
# 195143                     8324                   4604
# 195144                     8324                   4604
#
#         MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                        182357                   482453
# 1                          5045                    16426
# 2                            62                      165
# 3                             2                       21
# 4                            12                       34
# ...                         ...                      ...
# 195140                        6                        0
# 195141                     2378                     5592
# 195142                     2378                     5592
# 195143                     3720                     6762
# 195144                     3720                     6762
#
#         MainWorkersRuralMales  MainWorkersRuralFemales  \
# 0                      337954                   144499
# 1                       11949                     4477
# 2                         107                       58
# 3                          19                        2
# 4                          22                       12
# ...                       ...                      ...
# 195140                      0                        0
# 195141                   4090                     1502
# 195142                   4090                     1502
# 195143                   3974                     2788
# 195144                   3974                     2788
#
#         MainWorkersUrbanPersons  MainWorkersUrbanMales  \
# 0                        147626                 109768
# 1                          2465                   1897
# 2                            88                     84
# 3                            12                     12
# 4                             6                      6
# ...                         ...                    ...
# 195140                       18                     12
# 195141                     2652                   1776
# 195142                     2652                   1776
# 195143                     1562                    630
# 195144                     1562                    630
#
#         MainWorkersUrbanFemales  ...  MarginalWorkersRuralFemales  \
# 0                         37858  ...                       222431
# 1                           568  ...                        10803
# 2                             4  ...                          149
# 3                             0  ...                           19
# 4                             0  ...                           11
# ...                         ...  ...                          ...
# 195140                        6  ...                            0
# 195141                      876  ...                        14785
# 195142                      876  ...                        14785
# 195143                      932  ...                        10270
# 195144                      932  ...                        10270
#
#         MarginalWorkersUrbanPersons  MarginalWorkersUrbanMales  \
# 0                             35800                      20106
# 1                              1003                        573
# 2                                57                         27
# 3                                12                          6
# 4                                 5                          5
# ...                             ...                        ...
# 195140                            0                          0
# 195141                         3534                       1216
# 195142                         3534                       1216
# 195143                         1668                        418
# 195144                         1668                        418
#
#         MarginalWorkersUrbanFemales   State  District  TotalWorkers  \
# 0                             15694  ODISHA   Bargarh       1064141
# 1                               430  ODISHA   Bargarh         42292
# 2                                30  ODISHA   Bargarh           576
# 3                                 6  ODISHA   Bargarh            90
# 4                                 0  ODISHA   Bargarh            77
# ...                             ...     ...       ...           ...
# 195140                            0    WEST     Purba            18
# 195141                         2318    WEST     Purba         33835
# 195142                         2318    WEST     Purba         33835
# 195143                         1250    WEST     Purba         23196
# 195144                         1250    WEST     Purba         23196
#
#         MaleFemaleRatio  TotalPopulation WorkersRatio
# 0              2.455195          1064141            1
# 1              2.744500            42292            1
# 2              3.080645              576            1
# 3             15.500000               90            1
# 4              2.333333               77            1
# ...                 ...              ...          ...
# 195140         2.000000               18            1
# 195141         2.466779            33835            1
# 195142         2.466779            33835            1
# 195143         1.237634            23196            1
# 195144         1.237634            23196            1
#
# [195145 rows x 25 columns]

# %%
print(model.columns)
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio'],
#       dtype='object')

# %%
state_unique_values = model['State'].unique()
print(state_unique_values)
# Out:
# ['ODISHA' 'ASSAM' 'NAGALAND' 'SIKKIM' 'BIHAR' 'UTTAR' 'UTTARAKHAND'
#  'HIMACHAL' 'PUDUCHERRY' 'TAMIL' 'KERALA' 'GOA' 'KARNATAKA' 'MAHARASHTRA'
#  'GUJARAT' 'JHARKHAND' 'TRIPURA' 'NCT' 'MIZORAM' 'MANIPUR' 'ARUNACHAL'
#  'RAJASTHAN' 'WEST']

# %%
state_districts = model.groupby('State')['District'].unique()

for state, districts in state_districts.items():
    print(f"State: {state}")
    print("Districts:", ', '.join(districts))
    print("\n")
# Out:
# State: ARUNACHAL
# Districts: Tawang, West, East, Papum, Upper, Changlang, Tirap, Lower, Kurung, Dibang, Lohit, Anjaw
#
#
# State: ASSAM
# Districts: Kokrajhar, Dhubri, Goalpara, Barpeta, Morigaon, Nagaon, Sonitpur, Lakhimpur, Dhemaji, Tinsukia, Dibrugarh, Sivasagar, Jorhat, Golaghat, Karbi, Dima, Cachar, Karimganj, Hailakandi, Bongaigaon, Chirang, Kamrup, Nalbari, Baksa, Darrang, Udalguri
#
#
# State: BIHAR
# Districts: Pashchim, Purba, Sheohar, Sitamarhi, Madhubani, Supaul, Araria, Kishanganj, Purnia, Katihar, Madhepura, Saharsa, Darbhanga, Muzaffarpur, Gopalganj, Siwan, Saran, Vaishali, Samastipur, Begusarai, Khagaria, Bhagalpur, Banka, Munger, Lakhisarai, Sheikhpura, Nalanda, Patna, Bhojpur, Buxar, Kaimur, Rohtas, Aurangabad, Gaya, Nawada, Jamui, Jehanabad, Arwal
#
#
# State: GOA
# Districts: North, South
#
#
# State: GUJARAT
# Districts: Kachchh, Banas, Patan, Mahesana, Sabar, Gandhinagar, Ahmadabad, Surendranagar, Rajkot, Jamnagar, Porbandar, Junagadh, Amreli, Bhavnagar, Anand, Kheda, Panch, Dohad, Vadodara, Narmada, Bharuch, The, Navsari, Valsad, Surat, Tapi
#
#
# State: HIMACHAL
# Districts: Chamba, Kangra, Lahul, Kullu, Mandi, Hamirpur, Una, Bilaspur, Solan, Sirmaur, Shimla, Kinnaur
#
#
# State: JHARKHAND
# Districts: Garhwa, Chatra, Kodarma, Giridih, Deoghar, Godda, Sahibganj, Pakur, Dhanbad, Bokaro, Lohardaga, Purbi, Palamu, Latehar, Hazaribagh, Ramgarh, Dumka, Jamtara, Ranchi, Khunti, Gumla, Simdega, Pashchimi, Saraikela
#
#
# State: KARNATAKA
# Districts: Belgaum, Bagalkot, Bijapur, Bidar, Raichur, Koppal, Gadag, Dharwad, Uttara, Haveri, Bellary, Chitradurga, Davanagere, Shimoga, Udupi, Chikmagalur, Tumkur, Bangalore, Mandya, Hassan, Dakshina, Kodagu, Mysore, Chamarajanagar, Gulbarga, Yadgir, Kolar, Chikkaballapura, Ramanagara
#
#
# State: KERALA
# Districts: Kasaragod, Kannur, Wayanad, Kozhikode, Malappuram, Palakkad, Thrissur, Ernakulam, Idukki, Kottayam, Alappuzha, Pathanamthitta, Kollam, Thiruvananthapuram
#
#
# State: MAHARASHTRA
# Districts: Nandurbar, Dhule, Jalgaon, Buldana, Akola, Washim, Amravati, Wardha, Nagpur, Bhandara, Gondiya, Gadchiroli, Chandrapur, Yavatmal, Nanded, Hingoli, Parbhani, Jalna, Aurangabad, Nashik, Thane, Mumbai, Raigarh, Pune, Ahmadnagar, Bid, Latur, Osmanabad, Solapur, Satara, Ratnagiri, Sindhudurg, Kolhapur, Sangli
#
#
# State: MANIPUR
# Districts: Senapati, Tamenglong, Churachandpur, Bishnupur, Thoubal, Imphal, Ukhrul, Chandel
#
#
# State: MIZORAM
# Districts: Mamit, Kolasib, Aizawl, Champhai, Serchhip, Lunglei, Lawngtlai, Saiha
#
#
# State: NAGALAND
# Districts: Mon, Mokokchung, Zunheboto, Wokha, Dimapur, Phek, Tuensang, Longleng, Kiphire, Kohima, Peren
#
#
# State: NCT
# Districts: North, East, New, Central, West, South
#
#
# State: ODISHA
# Districts: Bargarh, Jharsuguda, Sambalpur, Debagarh, Sundargarh, Kendujhar, Mayurbhanj, Baleshwar, Bhadrak, Kendrapara, Jagatsinghapur, Cuttack, Jajapur, Dhenkanal, Anugul, Nayagarh, Khordha, Puri, Ganjam, Gajapati, Kandhamal, Baudh, Subarnapur, Balangir, Nuapada, Kalahandi, Rayagada, Nabarangapur, Koraput, Malkangiri
#
#
# State: PUDUCHERRY
# Districts: Yanam, Puducherry, Mahe, Karaikal
#
#
# State: RAJASTHAN
# Districts: Ganganagar, Hanumangarh, Bikaner, Churu, Jhunjhunun, Alwar, Bharatpur, Dhaulpur, Karauli, Sawai, Dausa, Jaipur, Sikar, Nagaur, Jodhpur, Jaisalmer, Barmer, Jalor, Sirohi, Pali, Ajmer, Tonk, Bundi, Bhilwara, Rajsamand, Dungarpur, Banswara, Chittaurgarh, Kota, Baran, Jhalawar, Udaipur, Pratapgarh
#
#
# State: SIKKIM
# Districts: North, West, South, East
#
#
# State: TAMIL
# Districts: Thiruvallur, Chennai, Kancheepuram, Vellore, Tiruvannamalai, Viluppuram, Salem, Namakkal, Erode, The, Dindigul, Karur, Tiruchirappalli, Perambalur, Ariyalur, Cuddalore, Nagapattinam, Thiruvarur, Thanjavur, Pudukkottai, Sivaganga, Madurai, Theni, Virudhunagar, Ramanathapuram, Thoothukkudi, Tirunelveli, Kanniyakumari, Dharmapuri, Krishnagiri, Coimbatore, Tiruppur
#
#
# State: TRIPURA
# Districts: West, South, Dhalai, North
#
#
# State: UTTAR
# Districts: Saharanpur, Muzaffarnagar, Bijnor, Moradabad, Rampur, Jyotiba, Meerut, Baghpat, Ghaziabad, Gautam, Bulandshahr, Aligarh, Mahamaya, Mathura, Agra, Firozabad, Mainpuri, Budaun, Bareilly, Pilibhit, Shahjahanpur, Kheri, Sitapur, Hardoi, Unnao, Lucknow, Rae, Farrukhabad, Kannauj, Etawah, Auraiya, Kanpur, Jalaun, Jhansi, Lalitpur, Hamirpur, Mahoba, Banda, Chitrakoot, Fatehpur, Pratapgarh, Kaushambi, Allahabad, Bara, Faizabad, Ambedkar, Sultanpur, Bahraich, Shrawasti, Balrampur, Gonda, Siddharthnagar, Basti, Sant, Mahrajganj, Gorakhpur, Kushinagar, Deoria, Azamgarh, Mau, Ballia, Jaunpur, Ghazipur, Chandauli, Varanasi, Mirzapur, Sonbhadra, Etah, Kanshiram
#
#
# State: UTTARAKHAND
# Districts: Uttarkashi, Chamoli, Rudraprayag, Tehri, Dehradun, Garhwal, Pithoragarh, Bageshwar, Almora, Champawat, Nainital, Udham, Hardwar
#
#
# State: WEST
# Districts: Darjiling, Jalpaiguri, Koch, Uttar, Dakshin, Maldah, Murshidabad, Birbhum, Barddhaman, Nadia, North, Hugli, Bankura, Puruliya, Haora, Kolkata, South, Paschim, Purba

# %%
import re
district_list  = ['District - Ganganagar',
       'District - Hanumangarh', 'District - Bikaner', 'District - Churu',
       'District - Jhunjhunun', 'District - Alwar',
       'District - Bharatpur', 'District - Dhaulpur',
       'District - Karauli', 'District - Sawai Madhopur',
       'District - Dausa', 'District - Jaipur', 'District - Sikar',
       'District - Nagaur', 'District - Jodhpur', 'District - Jaisalmer',
       'District - Barmer', 'District - Jalor', 'District - Sirohi',
       'District - Pali', 'District - Ajmer', 'District - Tonk',
       'District - Bundi', 'District - Bhilwara', 'District - Rajsamand',
       'District - Dungarpur', 'District - Banswara',
       'District - Chittaurgarh', 'District - Kota', 'District - Baran',
       'District - Jhalawar', 'District - Udaipur',
       'District - Pratapgarh']
unique_districts = list(set([re.sub(r'[^a-zA-Z0-9]', '', district.split(" - ")[1]) for district in district_list]))

# Print the result without quotes
print(', '.join(unique_districts))
# Out:
# Rajsamand, Udaipur, SawaiMadhopur, Nagaur, Bharatpur, Barmer, Bhilwara, Jalor, Sirohi, Jhalawar, Jaipur, Dhaulpur, Pali, Tonk, Baran, Pratapgarh, Banswara, Dausa, Alwar, Kota, Jodhpur, Bundi, Jhunjhunun, Churu, Karauli, Ajmer, Ganganagar, Bikaner, Hanumangarh, Dungarpur, Chittaurgarh, Sikar, Jaisalmer

# %%
df_2.to_csv("C:/Users/smm/Downloads/final_HR.csv", index = False)

# %%
new_st = pd.read_csv("C:/Users/smm/Downloads/final_HR.csv")
new_st.head(2)
# Out:
#                                              NICName  MainWorkersTotalPersons  \
# 0                                          ['total']                   630079
# 1  ['crop', 'animal', 'production', 'hunting', 'r...                    18891
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  MainWorkersRuralPersons  \
# 0                 447722                   182357                   482453
# 1                  13846                     5045                    16426
#
#    MainWorkersRuralMales  MainWorkersRuralFemales  MainWorkersUrbanPersons  \
# 0                 337954                   144499                   147626
# 1                  11949                     4477                     2465
#
#    MainWorkersUrbanMales  MainWorkersUrbanFemales  ...   State  District  \
# 0                 109768                    37858  ...  ODISHA   Bargarh
# 1                   1897                      568  ...  ODISHA   Bargarh
#
#    TotalWorkers  MaleFemaleRatio  TotalPopulation  WorkersRatio   latitude  \
# 0       1064141         2.455195          1064141             1  11.667026
# 1         42292         2.744500            42292             1  14.750429
#
#    longitude                                        NICName_str  \
# 0  92.735983                                              total
# 1  78.570026  crop animal production hunting related service...
#
#   sentiment_score
# 0             0.0
# 1             0.0
#
# [2 rows x 29 columns]

# %%
new_st.columns.unique
# Out:
# <bound method Index.unique of Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude', 'NICName_str',
#        'sentiment_score'],
#       dtype='object')>

# %%
unique_states = df_2['State'].unique()
unique_states
# Out:
# array(['ODISHA', 'ASSAM', 'NAGALAND', 'SIKKIM', 'BIHAR', 'UTTAR',
#        'UTTARAKHAND', 'HIMACHAL', 'PUDUCHERRY', 'TAMIL', 'KERALA', 'GOA',
#        'KARNATAKA', 'MAHARASHTRA', 'GUJARAT', 'JHARKHAND', 'TRIPURA',
#        'NCT', 'MIZORAM', 'MANIPUR', 'ARUNACHAL', 'RAJASTHAN', 'WEST'],
#       dtype=object)

# %% [markdown]
# St Page creation

# %%
# !pip install plotly
# !pip install streamlit
# Out:
# Requirement already satisfied: plotly in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (5.16.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from plotly) (23.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: streamlit in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (1.26.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.1.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: pillow<10,>=7.1.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (13.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (13.5.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.1.34)
# Requirement already satisfied: pydeck<1,>=0.8 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.0.0)
# Requirement already satisfied: jinja2 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.0)
# Requirement already satisfied: toolz in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.16.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\smm\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px
import streamlit as st

data = pd.read_csv("C:/Users/smm/Downloads/final_HR.csv")

unique_states = data['State'].unique()
unique_districts = data['District'].unique()
unique_nic_names = data['NICName'].unique()

selected_state = st.sidebar.selectbox("Select State", unique_states, key="state_selector")
selected_district = st.sidebar.selectbox("Select District", unique_districts, key="district_selector")

filtered_nic_names = data[data['District'] == selected_district]['NICName'].unique()
filtered_nic_names = [nic.replace('[', '').replace(']', '').replace("'", "") for nic in filtered_nic_names]
filtered_nic_names = [nic.capitalize() for nic in filtered_nic_names]
selected_nic_name = st.sidebar.selectbox("Select NIC Name", filtered_nic_names, key="nic_name_selector")


# #------------------------------------------------------------------------------------------------



# Plotting data for Rural, Main, and Urban workers
rural_cols = ['MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales']
urban_cols = ['MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales']

rural_data = data[rural_cols].sum().values
main_data = data[['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales']].iloc[0].values
urban_data = data[urban_cols].sum().values

# Plotting Rural, Main, and Urban data
fig, ax = plt.subplots(figsize=(10, 6))
x_labels = ['Rural', 'Main', 'Urban']
ax.bar(x_labels, rural_data, color='#1f77b4', label='Rural')
ax.bar(x_labels, main_data, bottom=rural_data, color='#ff7f0e', label='Main')
ax.bar(x_labels, urban_data, bottom=rural_data + main_data, color='#2ca02c', label='Urban')
ax.set_title(f"{selected_state} - {selected_district} - Workers Distribution")
ax.legend()
st.pyplot(fig)
# Out:
# 2024-02-28 07:42:14.963
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\smm\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
data['State'].unique()
# Out:
# array(['ODISHA', 'ASSAM', 'NAGALAND', 'SIKKIM', 'BIHAR', 'UTTAR',
#        'UTTARAKHAND', 'HIMACHAL', 'PUDUCHERRY', 'TAMIL', 'KERALA', 'GOA',
#        'KARNATAKA', 'MAHARASHTRA', 'GUJARAT', 'JHARKHAND', 'TRIPURA',
#        'NCT', 'MIZORAM', 'MANIPUR', 'ARUNACHAL', 'RAJASTHAN', 'WEST'],
#       dtype=object)

# %%
print(data.columns)
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude', 'NICName_str',
#        'sentiment_score'],
#       dtype='object')
